# %% [markdown]
# # Setup

# %%
# !pip uninstall -y kaggle kagglesdk
# !pip install kaggle wandb onnx -Uq
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Found existing installation: kaggle 1.7.4.5
# Uninstalling kaggle-1.7.4.5:
#   Successfully uninstalled kaggle-1.7.4.5
# WARNING: Skipping kagglesdk as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.4/86.4 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 138.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 96.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 145.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 22.0 MB/s eta 0:00:00
# Mounted at /content/drive

# %%
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json
# !echo "{\"username\":\"dachisuramelashvili\",\"key\":\"27a42d5900c0e3a2b31cb91648b983ef\"}" > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c gan-getting-started
# Out:
# Downloading gan-getting-started.zip to /content
#  96% 353M/367M [00:02<00:00, 175MB/s]
# 100% 367M/367M [00:02<00:00, 186MB/s]

# %%
# !unzip gan-getting-started.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: photo_jpg/46e84039a1.jpg
#   inflating: photo_jpg/46f391abec.jpg
#   inflating: photo_jpg/46f5ef1042.jpg
#   inflating: photo_jpg/4706619607.jpg
#   inflating: photo_jpg/4707b03a08.jpg
#   inflating: photo_jpg/47100a9939.jpg
#   inflating: photo_jpg/471f4755b9.jpg
#   inflating: photo_jpg/472b351bc4.jpg
#   inflating: photo_jpg/472d5ac100.jpg
#   inflating: photo_jpg/4758e5dd4c.jpg
#   inflating: photo_jpg/4762bb79ef.jpg
#   inflating: photo_jpg/4778b13518.jpg
#   inflating: photo_jpg/4787b82d37.jpg
#   inflating: photo_jpg/478e07feaa.jpg
#   inflating: photo_jpg/478eb12a82.jpg
#   inflating: photo_jpg/479698b371.jpg
#   inflating: photo_jpg/4796d67f61.jpg
#   inflating: photo_jpg/47aad493bd.jpg
#   inflating: photo_jpg/47ae0edd23.jpg
#   inflating: photo_jpg/47b94957ff.jpg
#   inflating: photo_jpg/47bb43fe3e.jpg
#   inflating: photo_jpg/47bb59d449.jpg
#   inflating: photo_jpg/47d391d94b.jpg
#   inflating: photo_jpg/47df262cc5.jpg
#   inflating: photo_jpg/47eea5bf33.jpg
#   inflating: photo_jpg/47f3b40cbc.jpg
#   inflating: photo_jpg/48122c9518.jpg
#   inflating: photo_jpg/481456b5a6.jpg
#   inflating: photo_jpg/481713d59d.jpg
#   inflating: photo_jpg/481bd32b6c.jpg
#   inflating: photo_jpg/482bf5a0d2.jpg
#   inflating: photo_jpg/482fd44fce.jpg
#   inflating: photo_jpg/4831466e23.jpg
#   inflating: photo_jpg/48502862cf.jpg
#   inflating: photo_jpg/485517e0c7.jpg
#   inflating: photo_jpg/48598ead29.jpg
#   inflating: photo_jpg/4862d17fa4.jpg
#   inflating: photo_jpg/486a62a430.jpg
#   inflating: photo_jpg/486cafaa7f.jpg
#   inflating: photo_jpg/48735c69aa.jpg
#   inflating: photo_jpg/48793755cd.jpg
#   inflating: photo_jpg/4879579e02.jpg
#   inflating: photo_jpg/488a6cef0c.jpg
#   inflating: photo_jpg/489c841af4.jpg
#   inflating: photo_jpg/48a85bc072.jpg
#   inflating: photo_jpg/48ac1011db.jpg
#   inflating: photo_jpg/48b6156f89.jpg
#   inflating: photo_jpg/48c641285b.jpg
#   inflating: photo_jpg/48e1a89d96.jpg
#   inflating: photo_jpg/48eac3916f.jpg
#   inflating: photo_jpg/48eb5fa7bd.jpg
#   inflating: photo_jpg/48f120810d.jpg
#   inflating: photo_jpg/49095bdeb5.jpg
#   inflating: photo_jpg/491b2ba38c.jpg
#   inflating: photo_jpg/49205c171d.jpg
#   inflating: photo_jpg/4943c84af0.jpg
#   inflating: photo_jpg/494db50238.jpg
#   inflating: photo_jpg/4950bcf8c1.jpg
#   inflating: photo_jpg/496757508b.jpg
#   inflating: photo_jpg/499b445583.jpg
#   inflating: photo_jpg/499bc1a152.jpg
#   inflating: photo_jpg/499c1bd3b8.jpg
#   inflating: photo_jpg/49a9692a0e.jpg
#   inflating: photo_jpg/49b093a9f3.jpg
#   inflating: photo_jpg/49b3383147.jpg
#   inflating: photo_jpg/49b8c4ea37.jpg
#   inflating: photo_jpg/49c2b1cdef.jpg
#   inflating: photo_jpg/49c538fce7.jpg
#   inflating: photo_jpg/49d2c9fc14.jpg
#   inflating: photo_jpg/49dc3fd195.jpg
#   inflating: photo_jpg/49e4129024.jpg
#   inflating: photo_jpg/49ee914a63.jpg
#   inflating: photo_jpg/4a06596662.jpg
#   inflating: photo_jpg/4a12f1780a.jpg
#   inflating: photo_jpg/4a16981927.jpg
#   inflating: photo_jpg/4a195405a0.jpg
#   inflating: photo_jpg/4a1bb1d46c.jpg
#   inflating: photo_jpg/4a20622bde.jpg
#   inflating: photo_jpg/4a29db3c6b.jpg
#   inflating: photo_jpg/4a2c4db283.jpg
#   inflating: photo_jpg/4a55695a4d.jpg
#   inflating: photo_jpg/4a5ab8f970.jpg
#   inflating: photo_jpg/4a669c897c.jpg
#   inflating: photo_jpg/4a7cec06e7.jpg
#   inflating: photo_jpg/4a8a49028d.jpg
#   inflating: photo_jpg/4a916ceb98.jpg
#   inflating: photo_jpg/4a9d34fa51.jpg
#   inflating: photo_jpg/4a9e982b39.jpg
#   inflating: photo_jpg/4aaf628a71.jpg
#   inflating: photo_jpg/4ab9478ef9.jpg
#   inflating: photo_jpg/4abaac9654.jpg
#   inflating: photo_jpg/4abd5654a3.jpg
#   inflating: photo_jpg/4abda75494.jpg
#   inflating: photo_jpg/4ac7c7bf44.jpg
#   inflating: photo_jpg/4ac8581018.jpg
#   inflating: photo_jpg/4ad0ccff25.jpg
#   inflating: photo_jpg/4adc8b7be7.jpg
#   inflating: photo_jpg/4ae0414bb9.jpg
#   inflating: photo_jpg/4ae09366f5.jpg
#   inflating: photo_jpg/4ae0b6efb2.jpg
#   inflating: photo_jpg/4ae5e1fb1d.jpg
#   inflating: photo_jpg/4b0025406f.jpg
#   inflating: photo_jpg/4b09444fe2.jpg
#   inflating: photo_jpg/4b0c0d7145.jpg
#   inflating: photo_jpg/4b0db938a7.jpg
#   inflating: photo_jpg/4b0f73833c.jpg
#   inflating: photo_jpg/4b14030c98.jpg
#   inflating: photo_jpg/4b2555ba9c.jpg
#   inflating: photo_jpg/4b29d9c42c.jpg
#   inflating: photo_jpg/4b2d102def.jpg
#   inflating: photo_jpg/4b3835e8ba.jpg
#   inflating: photo_jpg/4b3ccac37c.jpg
#   inflating: photo_jpg/4b47e76275.jpg
#   inflating: photo_jpg/4b497dc591.jpg
#   inflating: photo_jpg/4b59dd4ebc.jpg
#   inflating: photo_jpg/4b5a46b50f.jpg
#   inflating: photo_jpg/4b5b64dc18.jpg
#   inflating: photo_jpg/4b689e9b37.jpg
#   inflating: photo_jpg/4b7878976b.jpg
#   inflating: photo_jpg/4b7902dfa6.jpg
#   inflating: photo_jpg/4b7fc92bdc.jpg
#   inflating: photo_jpg/4b91cd8fce.jpg
#   inflating: photo_jpg/4b9eb29c59.jpg
#   inflating: photo_jpg/4bab53c613.jpg
#   inflating: photo_jpg/4bad1549a1.jpg
#   inflating: photo_jpg/4bbe0cbb3c.jpg
#   inflating: photo_jpg/4bd43d88d4.jpg
#   inflating: photo_jpg/4bd8ec5dd3.jpg
#   inflating: photo_jpg/4bdb933264.jpg
#   inflating: photo_jpg/4bdbdcc1e5.jpg
#   inflating: photo_jpg/4bdd197102.jpg
#   inflating: photo_jpg/4be248f682.jpg
#   inflating: photo_jpg/4bedb30dce.jpg
#   inflating: photo_jpg/4bef7510cb.jpg
#   inflating: photo_jpg/4bf1292d69.jpg
#   inflating: photo_jpg/4bfa3043e7.jpg
#   inflating: photo_jpg/4bfc3fbd84.jpg
#   inflating: photo_jpg/4bfed75eb2.jpg
#   inflating: photo_jpg/4c07909a8d.jpg
#   inflating: photo_jpg/4c1165be97.jpg
#   inflating: photo_jpg/4c16835970.jpg
#   inflating: photo_jpg/4c1907f1a0.jpg
#   inflating: photo_jpg/4c1b160563.jpg
#   inflating: photo_jpg/4c2d3216aa.jpg
#   inflating: photo_jpg/4c30ff85a7.jpg
#   inflating: photo_jpg/4c4574cfa8.jpg
#   inflating: photo_jpg/4c507b65b0.jpg
#   inflating: photo_jpg/4c6550cff5.jpg
#   inflating: photo_jpg/4c712561ab.jpg
#   inflating: photo_jpg/4c72792844.jpg
#   inflating: photo_jpg/4c75385f85.jpg
#   inflating: photo_jpg/4c7692cb0c.jpg
#   inflating: photo_jpg/4c7b54e38c.jpg
#   inflating: photo_jpg/4c8a000abb.jpg
#   inflating: photo_jpg/4c8bf22d16.jpg
#   inflating: photo_jpg/4c9669b6b8.jpg
#   inflating: photo_jpg/4ca019a3d6.jpg
#   inflating: photo_jpg/4ca57d26c0.jpg
#   inflating: photo_jpg/4ca6e5451a.jpg
#   inflating: photo_jpg/4cac88b518.jpg
#   inflating: photo_jpg/4cb25fbf3d.jpg
#   inflating: photo_jpg/4cb7c5e33d.jpg
#   inflating: photo_jpg/4cc42ebe97.jpg
#   inflating: photo_jpg/4ccc4a21e3.jpg
#   inflating: photo_jpg/4cd07a4561.jpg
#   inflating: photo_jpg/4cdd74b1c7.jpg
#   inflating: photo_jpg/4cf9aac018.jpg
#   inflating: photo_jpg/4cfdd2e627.jpg
#   inflating: photo_jpg/4d08cb65c3.jpg
#   inflating: photo_jpg/4d0a217b38.jpg
#   inflating: photo_jpg/4d0a274acb.jpg
#   inflating: photo_jpg/4d0eb41723.jpg
#   inflating: photo_jpg/4d1755ab04.jpg
#   inflating: photo_jpg/4d1c0b488e.jpg
#   inflating: photo_jpg/4d1c4d142e.jpg
#   inflating: photo_jpg/4d1d5efd4f.jpg
#   inflating: photo_jpg/4d3a7e5326.jpg
#   inflating: photo_jpg/4d42605a8b.jpg
#   inflating: photo_jpg/4d4b6bcac4.jpg
#   inflating: photo_jpg/4d4f0faddf.jpg
#   inflating: photo_jpg/4d4f388e91.jpg
#   inflating: photo_jpg/4d4f6174f1.jpg
#   inflating: photo_jpg/4d62a64806.jpg
#   inflating: photo_jpg/4d7188ff9e.jpg
#   inflating: photo_jpg/4d7517df48.jpg
#   inflating: photo_jpg/4d77636dea.jpg
#   inflating: photo_jpg/4d7de87ec6.jpg
#   inflating: photo_jpg/4d7fefe879.jpg
#   inflating: photo_jpg/4d83b23265.jpg
#   inflating: photo_jpg/4d90220636.jpg
#   inflating: photo_jpg/4d91831344.jpg
#   inflating: photo_jpg/4dc37726d9.jpg
#   inflating: photo_jpg/4dc92c4b4a.jpg
#   inflating: photo_jpg/4dd30f189a.jpg
#   inflating: photo_jpg/4df98eeceb.jpg
#   inflating: photo_jpg/4e093e9511.jpg
#   inflating: photo_jpg/4e0951fde1.jpg
#   inflating: photo_jpg/4e16ff77ac.jpg
#   inflating: photo_jpg/4e21145eb2.jpg
#   inflating: photo_jpg/4e2dba148d.jpg
#   inflating: photo_jpg/4e3006bd6b.jpg
#   inflating: photo_jpg/4e341f8891.jpg
#   inflating: photo_jpg/4e43b597e2.jpg
#   inflating: photo_jpg/4e4f75c4cc.jpg
#   inflating: photo_jpg/4e53db7c72.jpg
#   inflating: photo_jpg/4e5451ed74.jpg
#   inflating: photo_jpg/4e5b4fb2ab.jpg
#   inflating: photo_jpg/4e6e7f30da.jpg
#   inflating: photo_jpg/4e868f2a58.jpg
#   inflating: photo_jpg/4e880786c4.jpg
#   inflating: photo_jpg/4e8b01ac67.jpg
#   inflating: photo_jpg/4e8bd98343.jpg
#   inflating: photo_jpg/4e956f2cfb.jpg
#   inflating: photo_jpg/4ea19d4d05.jpg
#   inflating: photo_jpg/4eaa045ce6.jpg
#   inflating: photo_jpg/4eb3c1b0a7.jpg
#   inflating: photo_jpg/4ebb3df6e1.jpg
#   inflating: photo_jpg/4ec313a8cd.jpg
#   inflating: photo_jpg/4edd4fe6fa.jpg
#   inflating: photo_jpg/4ee02ffd2c.jpg
#   inflating: photo_jpg/4ef10f3299.jpg
#   inflating: photo_jpg/4f1249d8dc.jpg
#   inflating: photo_jpg/4f16e0bc95.jpg
#   inflating: photo_jpg/4f1fc68a47.jpg
#   inflating: photo_jpg/4f297a711e.jpg
#   inflating: photo_jpg/4f36d845b0.jpg
#   inflating: photo_jpg/4f38f2b8f5.jpg
#   inflating: photo_jpg/4f397d38d7.jpg
#   inflating: photo_jpg/4f5245105c.jpg
#   inflating: photo_jpg/4f5d5e7da3.jpg
#   inflating: photo_jpg/4f5e363609.jpg
#   inflating: photo_jpg/4f6353e80e.jpg
#   inflating: photo_jpg/4f64339fea.jpg
#   inflating: photo_jpg/4f697daf2d.jpg
#   inflating: photo_jpg/4f79b373f4.jpg
#   inflating: photo_jpg/4f83d232c2.jpg
#   inflating: photo_jpg/4f86f80479.jpg
#   inflating: photo_jpg/4f882d4400.jpg
#   inflating: photo_jpg/4f99708506.jpg
#   inflating: photo_jpg/4f9aa92ca3.jpg
#   inflating: photo_jpg/4fb5c1ac0a.jpg
#   inflating: photo_jpg/4fb6bcd5e8.jpg
#   inflating: photo_jpg/4fc41e388a.jpg
#   inflating: photo_jpg/4fc90f8de5.jpg
#   inflating: photo_jpg/4fc9c537a7.jpg
#   inflating: photo_jpg/4fd1d8afbf.jpg
#   inflating: photo_jpg/4fdaff583d.jpg
#   inflating: photo_jpg/4fe122209b.jpg
#   inflating: photo_jpg/4fe72a654e.jpg
#   inflating: photo_jpg/4ff4d77c99.jpg
#   inflating: photo_jpg/500d59cf86.jpg
#   inflating: photo_jpg/50115558cd.jpg
#   inflating: photo_jpg/501719248c.jpg
#   inflating: photo_jpg/5019a8ffcf.jpg
#   inflating: photo_jpg/5019d1eac7.jpg
#   inflating: photo_jpg/503c9badbb.jpg
#   inflating: photo_jpg/5048bb66c8.jpg
#   inflating: photo_jpg/504cec61a2.jpg
#   inflating: photo_jpg/504db35d13.jpg
#   inflating: photo_jpg/5050bd632b.jpg
#   inflating: photo_jpg/505850ed9f.jpg
#   inflating: photo_jpg/5065b423b0.jpg
#   inflating: photo_jpg/506fdcb3c1.jpg
#   inflating: photo_jpg/5074e8a51e.jpg
#   inflating: photo_jpg/50779f1ae6.jpg
#   inflating: photo_jpg/508f9ce48d.jpg
#   inflating: photo_jpg/50a42e1240.jpg
#   inflating: photo_jpg/50a5168133.jpg
#   inflating: photo_jpg/50b6593431.jpg
#   inflating: photo_jpg/50b8e79da2.jpg
#   inflating: photo_jpg/50c3f4beec.jpg
#   inflating: photo_jpg/50d9c1aa47.jpg
#   inflating: photo_jpg/50e2f57e76.jpg
#   inflating: photo_jpg/50e85855f5.jpg
#   inflating: photo_jpg/50e9fc6fdd.jpg
#   inflating: photo_jpg/50eb328bb2.jpg
#   inflating: photo_jpg/50f52bf9a4.jpg
#   inflating: photo_jpg/50f598c729.jpg
#   inflating: photo_jpg/50f7a05ee7.jpg
#   inflating: photo_jpg/51068cd053.jpg
#   inflating: photo_jpg/5116db8d92.jpg
#   inflating: photo_jpg/5117ec7f6b.jpg
#   inflating: photo_jpg/51279a61da.jpg
#   inflating: photo_jpg/5135f3ba21.jpg
#   inflating: photo_jpg/513cb0638a.jpg
#   inflating: photo_jpg/5140b80748.jpg
#   inflating: photo_jpg/514db4068a.jpg
#   inflating: photo_jpg/5155be81bf.jpg
#   inflating: photo_jpg/51563bc8ab.jpg
#   inflating: photo_jpg/516670d194.jpg
#   inflating: photo_jpg/51736e3772.jpg
#   inflating: photo_jpg/517eba9d0a.jpg
#   inflating: photo_jpg/51867bc005.jpg
#   inflating: photo_jpg/5194f65634.jpg
#   inflating: photo_jpg/519d3674c2.jpg
#   inflating: photo_jpg/519fc7c17a.jpg
#   inflating: photo_jpg/51aa9c9a20.jpg
#   inflating: photo_jpg/51dc50880b.jpg
#   inflating: photo_jpg/51e7037c03.jpg
#   inflating: photo_jpg/51ede123f3.jpg
#   inflating: photo_jpg/51ffb613ce.jpg
#   inflating: photo_jpg/52087dc0d6.jpg
#   inflating: photo_jpg/522a6dcbec.jpg
#   inflating: photo_jpg/523cbdab7d.jpg
#   inflating: photo_jpg/524223dfd9.jpg
#   inflating: photo_jpg/524af04df1.jpg
#   inflating: photo_jpg/524d00561a.jpg
#   inflating: photo_jpg/524fdda784.jpg
#   inflating: photo_jpg/52592fe2c6.jpg
#   inflating: photo_jpg/525952c058.jpg
#   inflating: photo_jpg/525f580c06.jpg
#   inflating: photo_jpg/5262b01633.jpg
#   inflating: photo_jpg/526b153062.jpg
#   inflating: photo_jpg/526dc07146.jpg
#   inflating: photo_jpg/527dd222d6.jpg
#   inflating: photo_jpg/527ddb23d4.jpg
#   inflating: photo_jpg/528058909d.jpg
#   inflating: photo_jpg/5280e2e8de.jpg
#   inflating: photo_jpg/5286eb8945.jpg
#   inflating: photo_jpg/529fa39eb2.jpg
#   inflating: photo_jpg/52a2a7132e.jpg
#   inflating: photo_jpg/52ae3cd25d.jpg
#   inflating: photo_jpg/52b870f300.jpg
#   inflating: photo_jpg/52bb31919e.jpg
#   inflating: photo_jpg/52bd17daa7.jpg
#   inflating: photo_jpg/52bee900da.jpg
#   inflating: photo_jpg/52cda09a5f.jpg
#   inflating: photo_jpg/52d8dbe113.jpg
#   inflating: photo_jpg/52e91ba9cf.jpg
#   inflating: photo_jpg/52f30bd94c.jpg
#   inflating: photo_jpg/52f641c328.jpg
#   inflating: photo_jpg/52f7801904.jpg
#   inflating: photo_jpg/5305c4063a.jpg
#   inflating: photo_jpg/5319435b3f.jpg
#   inflating: photo_jpg/53194986bc.jpg
#   inflating: photo_jpg/53289e47ec.jpg
#   inflating: photo_jpg/532d743269.jpg
#   inflating: photo_jpg/532f9d0621.jpg
#   inflating: photo_jpg/5338413448.jpg
#   inflating: photo_jpg/5338bd03be.jpg
#   inflating: photo_jpg/533be4e6eb.jpg
#   inflating: photo_jpg/5342ec67da.jpg
#   inflating: photo_jpg/534703a792.jpg
#   inflating: photo_jpg/53516d9b04.jpg
#   inflating: photo_jpg/53679e6985.jpg
#   inflating: photo_jpg/536c125b6f.jpg
#   inflating: photo_jpg/536c7edb2a.jpg
#   inflating: photo_jpg/537b155f3d.jpg
#   inflating: photo_jpg/537f558973.jpg
#   inflating: photo_jpg/53866d4a68.jpg
#   inflating: photo_jpg/5389fb4007.jpg
#   inflating: photo_jpg/53902a4799.jpg
#   inflating: photo_jpg/5395902bc7.jpg
#   inflating: photo_jpg/53988b72f6.jpg
#   inflating: photo_jpg/53989c56ff.jpg
#   inflating: photo_jpg/53998f50b2.jpg
#   inflating: photo_jpg/539e2ee021.jpg
#   inflating: photo_jpg/53b01e2132.jpg
#   inflating: photo_jpg/53b27f0c81.jpg
#   inflating: photo_jpg/53b835550d.jpg
#   inflating: photo_jpg/53bce35f0b.jpg
#   inflating: photo_jpg/53c245a6f3.jpg
#   inflating: photo_jpg/53d0160b46.jpg
#   inflating: photo_jpg/53d62fccce.jpg
#   inflating: photo_jpg/53e5b6b1b3.jpg
#   inflating: photo_jpg/53e766ae2b.jpg
#   inflating: photo_jpg/53ea60da05.jpg
#   inflating: photo_jpg/540649ac8c.jpg
#   inflating: photo_jpg/5407972e58.jpg
#   inflating: photo_jpg/5418378939.jpg
#   inflating: photo_jpg/54199dc11f.jpg
#   inflating: photo_jpg/5420c594aa.jpg
#   inflating: photo_jpg/5429ab574f.jpg
#   inflating: photo_jpg/5432eef613.jpg
#   inflating: photo_jpg/5435fdfdc4.jpg
#   inflating: photo_jpg/54381f3114.jpg
#   inflating: photo_jpg/543ea28da6.jpg
#   inflating: photo_jpg/5447d2bd8d.jpg
#   inflating: photo_jpg/54510d8755.jpg
#   inflating: photo_jpg/5451321dd0.jpg
#   inflating: photo_jpg/5452e17b68.jpg
#   inflating: photo_jpg/54538aea8b.jpg
#   inflating: photo_jpg/54557ef4cf.jpg
#   inflating: photo_jpg/54796e9027.jpg
#   inflating: photo_jpg/547ae945cb.jpg
#   inflating: photo_jpg/547c5615d1.jpg
#   inflating: photo_jpg/5484662dfb.jpg
#   inflating: photo_jpg/54b556920a.jpg
#   inflating: photo_jpg/54b6416b3a.jpg
#   inflating: photo_jpg/54b6bbf683.jpg
#   inflating: photo_jpg/54b8be5c1e.jpg
#   inflating: photo_jpg/54bf5ab7fd.jpg
#   inflating: photo_jpg/54d2feb575.jpg
#   inflating: photo_jpg/54e9e67501.jpg
#   inflating: photo_jpg/54f65afd1c.jpg
#   inflating: photo_jpg/55004786ef.jpg
#   inflating: photo_jpg/550956b456.jpg
#   inflating: photo_jpg/550b90e008.jpg
#   inflating: photo_jpg/55129db8f9.jpg
#   inflating: photo_jpg/5515a27184.jpg
#   inflating: photo_jpg/5519a2e240.jpg
#   inflating: photo_jpg/551afc0ef0.jpg
#   inflating: photo_jpg/55288a650b.jpg
#   inflating: photo_jpg/552aad92e5.jpg
#   inflating: photo_jpg/552b38a9bc.jpg
#   inflating: photo_jpg/55364f51f9.jpg
#   inflating: photo_jpg/5541538198.jpg
#   inflating: photo_jpg/5565d2e475.jpg
#   inflating: photo_jpg/5587066bdc.jpg
#   inflating: photo_jpg/558e78d813.jpg
#   inflating: photo_jpg/559359bcca.jpg
#   inflating: photo_jpg/55a74b7296.jpg
#   inflating: photo_jpg/55a8a07dde.jpg
#   inflating: photo_jpg/55a9c23538.jpg
#   inflating: photo_jpg/55ac4415ef.jpg
#   inflating: photo_jpg/55b015b4df.jpg
#   inflating: photo_jpg/55d0d2d4a1.jpg
#   inflating: photo_jpg/55e5a039c3.jpg
#   inflating: photo_jpg/5602c749d0.jpg
#   inflating: photo_jpg/5604c7533d.jpg
#   inflating: photo_jpg/5604ea3384.jpg
#   inflating: photo_jpg/5608b7a226.jpg
#   inflating: photo_jpg/5619b15af5.jpg
#   inflating: photo_jpg/561c1f7cde.jpg
#   inflating: photo_jpg/561d9722a4.jpg
#   inflating: photo_jpg/561e61d7f1.jpg
#   inflating: photo_jpg/561ec9ffaf.jpg
#   inflating: photo_jpg/5622447728.jpg
#   inflating: photo_jpg/56270960dc.jpg
#   inflating: photo_jpg/563012ee88.jpg
#   inflating: photo_jpg/56539880a8.jpg
#   inflating: photo_jpg/5654801d96.jpg
#   inflating: photo_jpg/565702bc95.jpg
#   inflating: photo_jpg/5681f45127.jpg
#   inflating: photo_jpg/56849b394d.jpg
#   inflating: photo_jpg/56884e5824.jpg
#   inflating: photo_jpg/568885cc54.jpg
#   inflating: photo_jpg/56894c4948.jpg
#   inflating: photo_jpg/568d52aa05.jpg
#   inflating: photo_jpg/568d92c4a7.jpg
#   inflating: photo_jpg/5694abf7fa.jpg
#   inflating: photo_jpg/569ed795ec.jpg
#   inflating: photo_jpg/56ac108ce7.jpg
#   inflating: photo_jpg/56ac1f673a.jpg
#   inflating: photo_jpg/56ac3dda09.jpg
#   inflating: photo_jpg/56bfd45d42.jpg
#   inflating: photo_jpg/56c6444a6d.jpg
#   inflating: photo_jpg/56c690f4ce.jpg
#   inflating: photo_jpg/56cb23c291.jpg
#   inflating: photo_jpg/56d2ce77d3.jpg
#   inflating: photo_jpg/56df48f901.jpg
#   inflating: photo_jpg/56e14fc1c7.jpg
#   inflating: photo_jpg/56e28bc581.jpg
#   inflating: photo_jpg/56e473c0df.jpg
#   inflating: photo_jpg/56e858f7c3.jpg
#   inflating: photo_jpg/5707c424dd.jpg
#   inflating: photo_jpg/571325ea85.jpg
#   inflating: photo_jpg/571a8540a2.jpg
#   inflating: photo_jpg/571c0614e4.jpg
#   inflating: photo_jpg/571da2a2b6.jpg
#   inflating: photo_jpg/572d08dd47.jpg
#   inflating: photo_jpg/5734dda15c.jpg
#   inflating: photo_jpg/573e2bc6ac.jpg
#   inflating: photo_jpg/573f3616e6.jpg
#   inflating: photo_jpg/57509041fb.jpg
#   inflating: photo_jpg/575796635b.jpg
#   inflating: photo_jpg/5757d9bb28.jpg
#   inflating: photo_jpg/5764c388a6.jpg
#   inflating: photo_jpg/5777167029.jpg
#   inflating: photo_jpg/5784a2edfb.jpg
#   inflating: photo_jpg/57874888f9.jpg
#   inflating: photo_jpg/5794fc49e9.jpg
#   inflating: photo_jpg/57965b2143.jpg
#   inflating: photo_jpg/579cd00684.jpg
#   inflating: photo_jpg/579d0d4e7d.jpg
#   inflating: photo_jpg/57a2330579.jpg
#   inflating: photo_jpg/57ba66fb37.jpg
#   inflating: photo_jpg/57bd2abf4c.jpg
#   inflating: photo_jpg/57c47a8905.jpg
#   inflating: photo_jpg/57c528a4d5.jpg
#   inflating: photo_jpg/57c906c4cf.jpg
#   inflating: photo_jpg/57cf047094.jpg
#   inflating: photo_jpg/57d109e9cf.jpg
#   inflating: photo_jpg/57dccccee3.jpg
#   inflating: photo_jpg/57e0bbe931.jpg
#   inflating: photo_jpg/57e301422d.jpg
#   inflating: photo_jpg/58111663f1.jpg
#   inflating: photo_jpg/581d539ad6.jpg
#   inflating: photo_jpg/5833188a28.jpg
#   inflating: photo_jpg/5834c44d37.jpg
#   inflating: photo_jpg/5847f64d5d.jpg
#   inflating: photo_jpg/5852bbcf34.jpg
#   inflating: photo_jpg/585a5eb514.jpg
#   inflating: photo_jpg/585aa1f933.jpg
#   inflating: photo_jpg/585efde177.jpg
#   inflating: photo_jpg/585f9cb26d.jpg
#   inflating: photo_jpg/586d359437.jpg
#   inflating: photo_jpg/5879d04028.jpg
#   inflating: photo_jpg/587a865f86.jpg
#   inflating: photo_jpg/587cc7c2fe.jpg
#   inflating: photo_jpg/5894a8daaa.jpg
#   inflating: photo_jpg/589b4cbb6e.jpg
#   inflating: photo_jpg/589fdf111c.jpg
#   inflating: photo_jpg/58a038ba43.jpg
#   inflating: photo_jpg/58a4b16894.jpg
#   inflating: photo_jpg/58a776400d.jpg
#   inflating: photo_jpg/58a9467f2f.jpg
#   inflating: photo_jpg/58ae62fe43.jpg
#   inflating: photo_jpg/58bd31f329.jpg
#   inflating: photo_jpg/58c1e36fda.jpg
#   inflating: photo_jpg/58cb8ad323.jpg
#   inflating: photo_jpg/58d3d98397.jpg
#   inflating: photo_jpg/58e34a0489.jpg
#   inflating: photo_jpg/5901773791.jpg
#   inflating: photo_jpg/590530447f.jpg
#   inflating: photo_jpg/5913ac7eed.jpg
#   inflating: photo_jpg/591d527b4e.jpg
#   inflating: photo_jpg/591df1353a.jpg
#   inflating: photo_jpg/59245494b6.jpg
#   inflating: photo_jpg/592bf31bd5.jpg
#   inflating: photo_jpg/592dd67bf2.jpg
#   inflating: photo_jpg/59344b7884.jpg
#   inflating: photo_jpg/593d5650ea.jpg
#   inflating: photo_jpg/593fa1789b.jpg
#   inflating: photo_jpg/594257c315.jpg
#   inflating: photo_jpg/5948efa988.jpg
#   inflating: photo_jpg/5966f03832.jpg
#   inflating: photo_jpg/5979ddaf40.jpg
#   inflating: photo_jpg/597dc8102b.jpg
#   inflating: photo_jpg/599d5b2041.jpg
#   inflating: photo_jpg/59a4aa8ae0.jpg
#   inflating: photo_jpg/59a5b56086.jpg
#   inflating: photo_jpg/59bf7066cc.jpg
#   inflating: photo_jpg/59c0b11f7a.jpg
#   inflating: photo_jpg/59c73a71e2.jpg
#   inflating: photo_jpg/59d87604af.jpg
#   inflating: photo_jpg/59f40fedcd.jpg
#   inflating: photo_jpg/5a086eb4d4.jpg
#   inflating: photo_jpg/5a0e4d57e3.jpg
#   inflating: photo_jpg/5a114c6f90.jpg
#   inflating: photo_jpg/5a1f5ac407.jpg
#   inflating: photo_jpg/5a234f081a.jpg
#   inflating: photo_jpg/5a294c5685.jpg
#   inflating: photo_jpg/5a29db5e43.jpg
#   inflating: photo_jpg/5a30d613e5.jpg
#   inflating: photo_jpg/5a384bf8d9.jpg
#   inflating: photo_jpg/5a3c04abea.jpg
#   inflating: photo_jpg/5a5b14d79d.jpg
#   inflating: photo_jpg/5a648082a7.jpg
#   inflating: photo_jpg/5a722db12a.jpg
#   inflating: photo_jpg/5a7cd923cb.jpg
#   inflating: photo_jpg/5a7fe873f4.jpg
#   inflating: photo_jpg/5a885d5128.jpg
#   inflating: photo_jpg/5a90fcd546.jpg
#   inflating: photo_jpg/5a921a3ab6.jpg
#   inflating: photo_jpg/5a977985f9.jpg
#   inflating: photo_jpg/5a9f9c1a61.jpg
#   inflating: photo_jpg/5aac6a791e.jpg
#   inflating: photo_jpg/5abbc037e1.jpg
#   inflating: photo_jpg/5ac7e3d633.jpg
#   inflating: photo_jpg/5ad9efc598.jpg
#   inflating: photo_jpg/5adb2c3de9.jpg
#   inflating: photo_jpg/5ae669f97f.jpg
#   inflating: photo_jpg/5ae67d7741.jpg
#   inflating: photo_jpg/5b1ac7d453.jpg
#   inflating: photo_jpg/5b1c17961a.jpg
#   inflating: photo_jpg/5b1ca92c81.jpg
#   inflating: photo_jpg/5b1ce21999.jpg
#   inflating: photo_jpg/5b25e416af.jpg
#   inflating: photo_jpg/5b28e861e1.jpg
#   inflating: photo_jpg/5b2c1cbcc1.jpg
#   inflating: photo_jpg/5b36970405.jpg
#   inflating: photo_jpg/5b39ba9b27.jpg
#   inflating: photo_jpg/5b3c9ac58f.jpg
#   inflating: photo_jpg/5b430536ec.jpg
#   inflating: photo_jpg/5b45458ccf.jpg
#   inflating: photo_jpg/5b47729366.jpg
#   inflating: photo_jpg/5b54acd95e.jpg
#   inflating: photo_jpg/5b5eae4414.jpg
#   inflating: photo_jpg/5b644de405.jpg
#   inflating: photo_jpg/5b67d44eea.jpg
#   inflating: photo_jpg/5b8f94e9ed.jpg
#   inflating: photo_jpg/5b960d2105.jpg
#   inflating: photo_jpg/5ba1f82d11.jpg
#   inflating: photo_jpg/5baec51613.jpg
#   inflating: photo_jpg/5bb0b7b0fd.jpg
#   inflating: photo_jpg/5bb7d3f1e2.jpg
#   inflating: photo_jpg/5bce397cd6.jpg
#   inflating: photo_jpg/5bdd158279.jpg
#   inflating: photo_jpg/5bddd2139f.jpg
#   inflating: photo_jpg/5bfc51adc2.jpg
#   inflating: photo_jpg/5c0287b212.jpg
#   inflating: photo_jpg/5c03d3796d.jpg
#   inflating: photo_jpg/5c04deef4e.jpg
#   inflating: photo_jpg/5c068c34b2.jpg
#   inflating: photo_jpg/5c096f6c6b.jpg
#   inflating: photo_jpg/5c097be130.jpg
#   inflating: photo_jpg/5c2de90d27.jpg
#   inflating: photo_jpg/5c3849313d.jpg
#   inflating: photo_jpg/5c399c47f2.jpg
#   inflating: photo_jpg/5c3afc56ce.jpg
#   inflating: photo_jpg/5c3d598219.jpg
#   inflating: photo_jpg/5c50599656.jpg
#   inflating: photo_jpg/5c556d2c26.jpg
#   inflating: photo_jpg/5c55bd3c02.jpg
#   inflating: photo_jpg/5c574cd9b7.jpg
#   inflating: photo_jpg/5c6144e5be.jpg
#   inflating: photo_jpg/5c6c72ff95.jpg
#   inflating: photo_jpg/5c8a36d364.jpg
#   inflating: photo_jpg/5c9487be68.jpg
#   inflating: photo_jpg/5c9979287f.jpg
#   inflating: photo_jpg/5c9b9f20eb.jpg
#   inflating: photo_jpg/5ca98fc2af.jpg
#   inflating: photo_jpg/5cb9dcf772.jpg
#   inflating: photo_jpg/5cc20cb7e7.jpg
#   inflating: photo_jpg/5ce9aaf1e0.jpg
#   inflating: photo_jpg/5cf2ea15af.jpg
#   inflating: photo_jpg/5cff9ca17c.jpg
#   inflating: photo_jpg/5d03870821.jpg
#   inflating: photo_jpg/5d10d088ee.jpg
#   inflating: photo_jpg/5d1671f99b.jpg
#   inflating: photo_jpg/5d1d521c3f.jpg
#   inflating: photo_jpg/5d23c3c935.jpg
#   inflating: photo_jpg/5d3ce96256.jpg
#   inflating: photo_jpg/5d4377db4a.jpg
#   inflating: photo_jpg/5d53f82763.jpg
#   inflating: photo_jpg/5d5d5c6cec.jpg
#   inflating: photo_jpg/5d77349c0e.jpg
#   inflating: photo_jpg/5d7b441aa9.jpg
#   inflating: photo_jpg/5d875c63ab.jpg
#   inflating: photo_jpg/5d87fdb2c6.jpg
#   inflating: photo_jpg/5d8939501e.jpg
#   inflating: photo_jpg/5d90dbd1ca.jpg
#   inflating: photo_jpg/5da725f8d7.jpg
#   inflating: photo_jpg/5da88da947.jpg
#   inflating: photo_jpg/5dcdf86cfb.jpg
#   inflating: photo_jpg/5dcfd3a36f.jpg
#   inflating: photo_jpg/5ddb1eae61.jpg
#   inflating: photo_jpg/5de7aa1645.jpg
#   inflating: photo_jpg/5ded03d0f9.jpg
#   inflating: photo_jpg/5e0062d8c4.jpg
#   inflating: photo_jpg/5e0082e751.jpg
#   inflating: photo_jpg/5e05579bfb.jpg
#   inflating: photo_jpg/5e0b43957f.jpg
#   inflating: photo_jpg/5e187eb93f.jpg
#   inflating: photo_jpg/5e23eef10f.jpg
#   inflating: photo_jpg/5e49c27b03.jpg
#   inflating: photo_jpg/5e4de25a9c.jpg
#   inflating: photo_jpg/5e5c74bded.jpg
#   inflating: photo_jpg/5e62cdccf1.jpg
#   inflating: photo_jpg/5e64b64de8.jpg
#   inflating: photo_jpg/5e80458f0d.jpg
#   inflating: photo_jpg/5e8a5f5d3b.jpg
#   inflating: photo_jpg/5e8afd118f.jpg
#   inflating: photo_jpg/5e9b6ee1a4.jpg
#   inflating: photo_jpg/5e9d609ee7.jpg
#   inflating: photo_jpg/5e9f0eec0c.jpg
#   inflating: photo_jpg/5ea13d56aa.jpg
#   inflating: photo_jpg/5eaccc99bf.jpg
#   inflating: photo_jpg/5eb792b2be.jpg
#   inflating: photo_jpg/5ed2785909.jpg
#   inflating: photo_jpg/5ed86a6d0b.jpg
#   inflating: photo_jpg/5edefd0d0f.jpg
#   inflating: photo_jpg/5ee0ea499b.jpg
#   inflating: photo_jpg/5ee88f0c5f.jpg
#   inflating: photo_jpg/5ee96ba98d.jpg
#   inflating: photo_jpg/5ef70f37ea.jpg
#   inflating: photo_jpg/5f02c26178.jpg
#   inflating: photo_jpg/5f0d21c2b1.jpg
#   inflating: photo_jpg/5f14f7641d.jpg
#   inflating: photo_jpg/5f24335241.jpg
#   inflating: photo_jpg/5f25cbc263.jpg
#   inflating: photo_jpg/5f2b8fa71a.jpg
#   inflating: photo_jpg/5f34ec2686.jpg
#   inflating: photo_jpg/5f4018d615.jpg
#   inflating: photo_jpg/5f4612d92b.jpg
#   inflating: photo_jpg/5f477576c5.jpg
#   inflating: photo_jpg/5f477a5c46.jpg
#   inflating: photo_jpg/5f674f802b.jpg
#   inflating: photo_jpg/5f6acdd885.jpg
#   inflating: photo_jpg/5f7a943ad3.jpg
#   inflating: photo_jpg/5f824e47e4.jpg
#   inflating: photo_jpg/5fb5327415.jpg
#   inflating: photo_jpg/5fcf902716.jpg
#   inflating: photo_jpg/5fd438d742.jpg
#   inflating: photo_jpg/5ff7a6bd52.jpg
#   inflating: photo_jpg/5fffc71069.jpg
#   inflating: photo_jpg/600adb121f.jpg
#   inflating: photo_jpg/60149bcbbf.jpg
#   inflating: photo_jpg/60268cfb2f.jpg
#   inflating: photo_jpg/604547096b.jpg
#   inflating: photo_jpg/6045dd5804.jpg
#   inflating: photo_jpg/604c154a10.jpg
#   inflating: photo_jpg/604d51ecdb.jpg
#   inflating: photo_jpg/604eee6de2.jpg
#   inflating: photo_jpg/6058fe8ba4.jpg
#   inflating: photo_jpg/605c399821.jpg
#   inflating: photo_jpg/606bc88bf5.jpg
#   inflating: photo_jpg/606ea8c853.jpg
#   inflating: photo_jpg/606edf9e69.jpg
#   inflating: photo_jpg/607508ca60.jpg
#   inflating: photo_jpg/6090cac2ca.jpg
#   inflating: photo_jpg/609699b9f5.jpg
#   inflating: photo_jpg/6099732dd8.jpg
#   inflating: photo_jpg/60a6fdd5c0.jpg
#   inflating: photo_jpg/60ac278e96.jpg
#   inflating: photo_jpg/60adaaa8fa.jpg
#   inflating: photo_jpg/60ee84f0e3.jpg
#   inflating: photo_jpg/60f455c446.jpg
#   inflating: photo_jpg/60f7b3ce84.jpg
#   inflating: photo_jpg/60fa0dced3.jpg
#   inflating: photo_jpg/610b2e40b1.jpg
#   inflating: photo_jpg/610ff29105.jpg
#   inflating: photo_jpg/6113839c53.jpg
#   inflating: photo_jpg/611ce907ee.jpg
#   inflating: photo_jpg/6127261426.jpg
#   inflating: photo_jpg/612de09c0e.jpg
#   inflating: photo_jpg/612eb28781.jpg
#   inflating: photo_jpg/613592c5ba.jpg
#   inflating: photo_jpg/614aebf996.jpg
#   inflating: photo_jpg/614dcbd1b6.jpg
#   inflating: photo_jpg/614e5368b3.jpg
#   inflating: photo_jpg/6157aa63b5.jpg
#   inflating: photo_jpg/615f1a41e2.jpg
#   inflating: photo_jpg/6163883314.jpg
#   inflating: photo_jpg/6165bb7d20.jpg
#   inflating: photo_jpg/618573a4c0.jpg
#   inflating: photo_jpg/618c3a93a6.jpg
#   inflating: photo_jpg/619868817c.jpg
#   inflating: photo_jpg/61c0bf55f3.jpg
#   inflating: photo_jpg/61ca26c3f0.jpg
#   inflating: photo_jpg/61d1dacb0a.jpg
#   inflating: photo_jpg/61e0412438.jpg
#   inflating: photo_jpg/61efe98c2b.jpg
#   inflating: photo_jpg/61f0619994.jpg
#   inflating: photo_jpg/61f337301f.jpg
#   inflating: photo_jpg/61f79ea5e3.jpg
#   inflating: photo_jpg/61febf655e.jpg
#   inflating: photo_jpg/6203a47be6.jpg
#   inflating: photo_jpg/6203de934f.jpg
#   inflating: photo_jpg/6203e44a0b.jpg
#   inflating: photo_jpg/6216948548.jpg
#   inflating: photo_jpg/623226574f.jpg
#   inflating: photo_jpg/6233033047.jpg
#   inflating: photo_jpg/6233a14e7a.jpg
#   inflating: photo_jpg/62428234ef.jpg
#   inflating: photo_jpg/62556af40e.jpg
#   inflating: photo_jpg/6256e7fb82.jpg
#   inflating: photo_jpg/62601c808e.jpg
#   inflating: photo_jpg/626caaa1ce.jpg
#   inflating: photo_jpg/627532c78c.jpg
#   inflating: photo_jpg/6276c2f781.jpg
#   inflating: photo_jpg/6280ca0cf1.jpg
#   inflating: photo_jpg/6297c1fc75.jpg
#   inflating: photo_jpg/62a4327b05.jpg
#   inflating: photo_jpg/62a86886a4.jpg
#   inflating: photo_jpg/62ada6e480.jpg
#   inflating: photo_jpg/62ae12c529.jpg
#   inflating: photo_jpg/62b043985f.jpg
#   inflating: photo_jpg/62b1939e2e.jpg
#   inflating: photo_jpg/62b6c6c11d.jpg
#   inflating: photo_jpg/62bb8501e8.jpg
#   inflating: photo_jpg/62bff6d96f.jpg
#   inflating: photo_jpg/62c54774f6.jpg
#   inflating: photo_jpg/62c5a2a3c0.jpg
#   inflating: photo_jpg/62c8619eeb.jpg
#   inflating: photo_jpg/62e2c15e98.jpg
#   inflating: photo_jpg/62e79f1dd2.jpg
#   inflating: photo_jpg/630d324a16.jpg
#   inflating: photo_jpg/631cc9e7d1.jpg
#   inflating: photo_jpg/631f90f7a9.jpg
#   inflating: photo_jpg/632020c3e8.jpg
#   inflating: photo_jpg/632858e7c4.jpg
#   inflating: photo_jpg/633128bbae.jpg
#   inflating: photo_jpg/6334aea3e0.jpg
#   inflating: photo_jpg/63372e9038.jpg
#   inflating: photo_jpg/633edb47c9.jpg
#   inflating: photo_jpg/634246cbc0.jpg
#   inflating: photo_jpg/634e2ff9c5.jpg
#   inflating: photo_jpg/634f5cf142.jpg
#   inflating: photo_jpg/635907bad9.jpg
#   inflating: photo_jpg/6360e41e69.jpg
#   inflating: photo_jpg/636280c73d.jpg
#   inflating: photo_jpg/636d76c49a.jpg
#   inflating: photo_jpg/6376737353.jpg
#   inflating: photo_jpg/6376c3ffa5.jpg
#   inflating: photo_jpg/6379773e3f.jpg
#   inflating: photo_jpg/637a28f9cf.jpg
#   inflating: photo_jpg/638093f853.jpg
#   inflating: photo_jpg/6383f39af4.jpg
#   inflating: photo_jpg/63959943dd.jpg
#   inflating: photo_jpg/639ed4c744.jpg
#   inflating: photo_jpg/63a0582761.jpg
#   inflating: photo_jpg/63b4aeae20.jpg
#   inflating: photo_jpg/63b6bc086c.jpg
#   inflating: photo_jpg/63bf7ae1cf.jpg
#   inflating: photo_jpg/63d194e1df.jpg
#   inflating: photo_jpg/63e007e789.jpg
#   inflating: photo_jpg/63e73c1dc9.jpg
#   inflating: photo_jpg/63e885e644.jpg
#   inflating: photo_jpg/63f6cea734.jpg
#   inflating: photo_jpg/63fef59198.jpg
#   inflating: photo_jpg/6401c2d6c0.jpg
#   inflating: photo_jpg/6417787af0.jpg
#   inflating: photo_jpg/6421360d4f.jpg
#   inflating: photo_jpg/64247b3eb5.jpg
#   inflating: photo_jpg/6431f96d10.jpg
#   inflating: photo_jpg/64356423f2.jpg
#   inflating: photo_jpg/6438b04e89.jpg
#   inflating: photo_jpg/643916e05b.jpg
#   inflating: photo_jpg/64397cbb62.jpg
#   inflating: photo_jpg/6440dd45f8.jpg
#   inflating: photo_jpg/6444bc3ca4.jpg
#   inflating: photo_jpg/6447774e95.jpg
#   inflating: photo_jpg/6457f79ca3.jpg
#   inflating: photo_jpg/646da34032.jpg
#   inflating: photo_jpg/64813f537a.jpg
#   inflating: photo_jpg/6493077860.jpg
#   inflating: photo_jpg/649df99535.jpg
#   inflating: photo_jpg/64a519abd0.jpg
#   inflating: photo_jpg/64bd39e960.jpg
#   inflating: photo_jpg/64c68d0aa3.jpg
#   inflating: photo_jpg/64c6b6a511.jpg
#   inflating: photo_jpg/64cf019733.jpg
#   inflating: photo_jpg/64d0a7acf2.jpg
#   inflating: photo_jpg/64d362378f.jpg
#   inflating: photo_jpg/64e21dfda0.jpg
#   inflating: photo_jpg/64ee7530ff.jpg
#   inflating: photo_jpg/64f06b5ceb.jpg
#   inflating: photo_jpg/64fcd56944.jpg
#   inflating: photo_jpg/6533b9656e.jpg
#   inflating: photo_jpg/65344ad883.jpg
#   inflating: photo_jpg/653774f59a.jpg
#   inflating: photo_jpg/654dce0bc5.jpg
#   inflating: photo_jpg/6558098202.jpg
#   inflating: photo_jpg/6561bd46ba.jpg
#   inflating: photo_jpg/657337796d.jpg
#   inflating: photo_jpg/657a1ebe3d.jpg
#   inflating: photo_jpg/657bf0b295.jpg
#   inflating: photo_jpg/657d970481.jpg
#   inflating: photo_jpg/65881ff201.jpg
#   inflating: photo_jpg/6589904ec0.jpg
#   inflating: photo_jpg/65a09899f8.jpg
#   inflating: photo_jpg/65a6d3e7e2.jpg
#   inflating: photo_jpg/65ba65db68.jpg
#   inflating: photo_jpg/65cf11fe0e.jpg
#   inflating: photo_jpg/65e0307c38.jpg
#   inflating: photo_jpg/65e1c3f768.jpg
#   inflating: photo_jpg/65eb33194f.jpg
#   inflating: photo_jpg/65f48bdd36.jpg
#   inflating: photo_jpg/65ff1c4226.jpg
#   inflating: photo_jpg/660a638976.jpg
#   inflating: photo_jpg/661aadc417.jpg
#   inflating: photo_jpg/661d51efae.jpg
#   inflating: photo_jpg/662c5c4ff4.jpg
#   inflating: photo_jpg/6635a31ee1.jpg
#   inflating: photo_jpg/66361eea70.jpg
#   inflating: photo_jpg/6639b516d5.jpg
#   inflating: photo_jpg/663b9a1924.jpg
#   inflating: photo_jpg/66488583ab.jpg
#   inflating: photo_jpg/664b161ecc.jpg
#   inflating: photo_jpg/667c0fd61b.jpg
#   inflating: photo_jpg/6690a30a29.jpg
#   inflating: photo_jpg/66ad36a8d6.jpg
#   inflating: photo_jpg/66af3aa4b1.jpg
#   inflating: photo_jpg/66b54569e6.jpg
#   inflating: photo_jpg/66cb408c30.jpg
#   inflating: photo_jpg/66db0fe6b4.jpg
#   inflating: photo_jpg/66dbf73abc.jpg
#   inflating: photo_jpg/66e71841a4.jpg
#   inflating: photo_jpg/66f8456cb7.jpg
#   inflating: photo_jpg/6700b4b7bb.jpg
#   inflating: photo_jpg/670d9aa07f.jpg
#   inflating: photo_jpg/670dbb29d1.jpg
#   inflating: photo_jpg/6717eca3cc.jpg
#   inflating: photo_jpg/6728f4bba7.jpg
#   inflating: photo_jpg/6731de7cdc.jpg
#   inflating: photo_jpg/6736ee186d.jpg
#   inflating: photo_jpg/674bf68b95.jpg
#   inflating: photo_jpg/674c25f70e.jpg
#   inflating: photo_jpg/6751643b4b.jpg
#   inflating: photo_jpg/675e6b6065.jpg
#   inflating: photo_jpg/675eb73e32.jpg
#   inflating: photo_jpg/676a38fcf2.jpg
#   inflating: photo_jpg/676d2377ea.jpg
#   inflating: photo_jpg/67811f844f.jpg
#   inflating: photo_jpg/6798a2a50d.jpg
#   inflating: photo_jpg/679f2b8c09.jpg
#   inflating: photo_jpg/67ad9f90eb.jpg
#   inflating: photo_jpg/67ae13d8fd.jpg
#   inflating: photo_jpg/67b03b9ae6.jpg
#   inflating: photo_jpg/67b2023cdc.jpg
#   inflating: photo_jpg/67b303bc1f.jpg
#   inflating: photo_jpg/67bf2caa0d.jpg
#   inflating: photo_jpg/67cb59fe1b.jpg
#   inflating: photo_jpg/67d30c5976.jpg
#   inflating: photo_jpg/67e82318a8.jpg
#   inflating: photo_jpg/67fa0b1fff.jpg
#   inflating: photo_jpg/67ffae436a.jpg
#   inflating: photo_jpg/680e403ee6.jpg
#   inflating: photo_jpg/68161f940a.jpg
#   inflating: photo_jpg/681747f03e.jpg
#   inflating: photo_jpg/681949c029.jpg
#   inflating: photo_jpg/681df42505.jpg
#   inflating: photo_jpg/682e0844c2.jpg
#   inflating: photo_jpg/6836334767.jpg
#   inflating: photo_jpg/683ff91f55.jpg
#   inflating: photo_jpg/684690671a.jpg
#   inflating: photo_jpg/684be8790c.jpg
#   inflating: photo_jpg/685174f022.jpg
#   inflating: photo_jpg/6852f4cb2d.jpg
#   inflating: photo_jpg/685923a424.jpg
#   inflating: photo_jpg/68730b2016.jpg
#   inflating: photo_jpg/687cd30117.jpg
#   inflating: photo_jpg/6884abf5fe.jpg
#   inflating: photo_jpg/6887ee7059.jpg
#   inflating: photo_jpg/688fd65571.jpg
#   inflating: photo_jpg/689273b092.jpg
#   inflating: photo_jpg/68a0fd8800.jpg
#   inflating: photo_jpg/68b8b35955.jpg
#   inflating: photo_jpg/68d3757ce1.jpg
#   inflating: photo_jpg/68d785f0cb.jpg
#   inflating: photo_jpg/68e40889bf.jpg
#   inflating: photo_jpg/68e93f1dd4.jpg
#   inflating: photo_jpg/68f7232a89.jpg
#   inflating: photo_jpg/6915fdb4e2.jpg
#   inflating: photo_jpg/692b29e496.jpg
#   inflating: photo_jpg/692d2be632.jpg
#   inflating: photo_jpg/6932043ee0.jpg
#   inflating: photo_jpg/693415a29b.jpg
#   inflating: photo_jpg/69552238b4.jpg
#   inflating: photo_jpg/695755652f.jpg
#   inflating: photo_jpg/6957a4b495.jpg
#   inflating: photo_jpg/6960ca7470.jpg
#   inflating: photo_jpg/6960d1ca6a.jpg
#   inflating: photo_jpg/696803e17c.jpg
#   inflating: photo_jpg/696f56514d.jpg
#   inflating: photo_jpg/6970d5e39a.jpg
#   inflating: photo_jpg/697a7cac68.jpg
#   inflating: photo_jpg/6987bc04a8.jpg
#   inflating: photo_jpg/69a48c1703.jpg
#   inflating: photo_jpg/69ae5108fc.jpg
#   inflating: photo_jpg/69b2d90a15.jpg
#   inflating: photo_jpg/69b411b727.jpg
#   inflating: photo_jpg/69b590e268.jpg
#   inflating: photo_jpg/69ba3dbcbe.jpg
#   inflating: photo_jpg/69bc2bf220.jpg
#   inflating: photo_jpg/69c3dba202.jpg
#   inflating: photo_jpg/69c50db73f.jpg
#   inflating: photo_jpg/69c5eb1184.jpg
#   inflating: photo_jpg/69ce40e8bd.jpg
#   inflating: photo_jpg/69cf4ee0c1.jpg
#   inflating: photo_jpg/69e5be6684.jpg
#   inflating: photo_jpg/69ea18eac3.jpg
#   inflating: photo_jpg/69ff61709e.jpg
#   inflating: photo_jpg/6a0a168174.jpg
#   inflating: photo_jpg/6a0c1b662f.jpg
#   inflating: photo_jpg/6a19d6ed16.jpg
#   inflating: photo_jpg/6a1aea3e32.jpg
#   inflating: photo_jpg/6a24142aad.jpg
#   inflating: photo_jpg/6a3a6192c0.jpg
#   inflating: photo_jpg/6a4d3daafe.jpg
#   inflating: photo_jpg/6a4fe6590b.jpg
#   inflating: photo_jpg/6a55ec45aa.jpg
#   inflating: photo_jpg/6a5b3e97df.jpg
#   inflating: photo_jpg/6a62792333.jpg
#   inflating: photo_jpg/6a6fb64128.jpg
#   inflating: photo_jpg/6a75bc4fce.jpg
#   inflating: photo_jpg/6a95e80280.jpg
#   inflating: photo_jpg/6a9634ff0e.jpg
#   inflating: photo_jpg/6aa027975d.jpg
#   inflating: photo_jpg/6ab55e39e3.jpg
#   inflating: photo_jpg/6ab607ca91.jpg
#   inflating: photo_jpg/6ac584cbb4.jpg
#   inflating: photo_jpg/6ac922afab.jpg
#   inflating: photo_jpg/6ae1292f67.jpg
#   inflating: photo_jpg/6afc612209.jpg
#   inflating: photo_jpg/6b04d109cf.jpg
#   inflating: photo_jpg/6b240d89b8.jpg
#   inflating: photo_jpg/6b25e23139.jpg
#   inflating: photo_jpg/6b3e7692a0.jpg
#   inflating: photo_jpg/6b47c83dad.jpg
#   inflating: photo_jpg/6b53db36ed.jpg
#   inflating: photo_jpg/6b61c7852e.jpg
#   inflating: photo_jpg/6b66f3c48a.jpg
#   inflating: photo_jpg/6b6b85cd53.jpg
#   inflating: photo_jpg/6b6e1046b8.jpg
#   inflating: photo_jpg/6b70c93481.jpg
#   inflating: photo_jpg/6b7172639a.jpg
#   inflating: photo_jpg/6b87a7b5dc.jpg
#   inflating: photo_jpg/6b87dc38dc.jpg
#   inflating: photo_jpg/6b910e1321.jpg
#   inflating: photo_jpg/6ba72ca483.jpg
#   inflating: photo_jpg/6bb4d6273a.jpg
#   inflating: photo_jpg/6bc014d8ea.jpg
#   inflating: photo_jpg/6bc2744034.jpg
#   inflating: photo_jpg/6bc4af390a.jpg
#   inflating: photo_jpg/6bc7d64fb6.jpg
#   inflating: photo_jpg/6bc8104d76.jpg
#   inflating: photo_jpg/6bcd8876a4.jpg
#   inflating: photo_jpg/6bcea12f74.jpg
#   inflating: photo_jpg/6be0fc09a5.jpg
#   inflating: photo_jpg/6bf0976dae.jpg
#   inflating: photo_jpg/6c0f6804c5.jpg
#   inflating: photo_jpg/6c19b70453.jpg
#   inflating: photo_jpg/6c1d743ded.jpg
#   inflating: photo_jpg/6c1f308e02.jpg
#   inflating: photo_jpg/6c28209b0b.jpg
#   inflating: photo_jpg/6c37caaa86.jpg
#   inflating: photo_jpg/6c38e65dd9.jpg
#   inflating: photo_jpg/6c5fb319c2.jpg
#   inflating: photo_jpg/6c650608d2.jpg
#   inflating: photo_jpg/6c66f26b82.jpg
#   inflating: photo_jpg/6c77b100ea.jpg
#   inflating: photo_jpg/6c7b92564c.jpg
#   inflating: photo_jpg/6c7bd28db6.jpg
#   inflating: photo_jpg/6c7e5b0199.jpg
#   inflating: photo_jpg/6c8aec68c1.jpg
#   inflating: photo_jpg/6c8c8234e4.jpg
#   inflating: photo_jpg/6c9c20101d.jpg
#   inflating: photo_jpg/6cad5acca6.jpg
#   inflating: photo_jpg/6cada09ad0.jpg
#   inflating: photo_jpg/6cb683712d.jpg
#   inflating: photo_jpg/6cb7a4d1c0.jpg
#   inflating: photo_jpg/6cc9ba090d.jpg
#   inflating: photo_jpg/6cdb4ae67d.jpg
#   inflating: photo_jpg/6cf14b58ac.jpg
#   inflating: photo_jpg/6d21dd8e8a.jpg
#   inflating: photo_jpg/6d2db478f1.jpg
#   inflating: photo_jpg/6d366256a0.jpg
#   inflating: photo_jpg/6d43871d17.jpg
#   inflating: photo_jpg/6d4cd97a65.jpg
#   inflating: photo_jpg/6d4ed509c4.jpg
#   inflating: photo_jpg/6d59401909.jpg
#   inflating: photo_jpg/6d6717a60d.jpg
#   inflating: photo_jpg/6d6bc1579a.jpg
#   inflating: photo_jpg/6d75effae7.jpg
#   inflating: photo_jpg/6d76ac5983.jpg
#   inflating: photo_jpg/6d76db2739.jpg
#   inflating: photo_jpg/6d8ac0ab87.jpg
#   inflating: photo_jpg/6d8ff7415d.jpg
#   inflating: photo_jpg/6da5f24eb5.jpg
#   inflating: photo_jpg/6da926571e.jpg
#   inflating: photo_jpg/6db9d90f11.jpg
#   inflating: photo_jpg/6dc8ab590e.jpg
#   inflating: photo_jpg/6dce9829bb.jpg
#   inflating: photo_jpg/6dcf799703.jpg
#   inflating: photo_jpg/6ddc86d0e4.jpg
#   inflating: photo_jpg/6dee6d02d8.jpg
#   inflating: photo_jpg/6df48d411c.jpg
#   inflating: photo_jpg/6dfff386db.jpg
#   inflating: photo_jpg/6e09fe8d32.jpg
#   inflating: photo_jpg/6e13b2f9b4.jpg
#   inflating: photo_jpg/6e17babca8.jpg
#   inflating: photo_jpg/6e2493f8d4.jpg
#   inflating: photo_jpg/6e2c4451e5.jpg
#   inflating: photo_jpg/6e3c226e32.jpg
#   inflating: photo_jpg/6e3e179ef8.jpg
#   inflating: photo_jpg/6e57dbfe6f.jpg
#   inflating: photo_jpg/6e5cd72d3c.jpg
#   inflating: photo_jpg/6e656030a0.jpg
#   inflating: photo_jpg/6e68264904.jpg
#   inflating: photo_jpg/6e72f8ad6c.jpg
#   inflating: photo_jpg/6e84325bee.jpg
#   inflating: photo_jpg/6e89ef391e.jpg
#   inflating: photo_jpg/6e8ec08b46.jpg
#   inflating: photo_jpg/6e924c87a3.jpg
#   inflating: photo_jpg/6e9f6935ce.jpg
#   inflating: photo_jpg/6ea4aef23e.jpg
#   inflating: photo_jpg/6ebd91c7e5.jpg
#   inflating: photo_jpg/6ebfe9870b.jpg
#   inflating: photo_jpg/6ec425bb69.jpg
#   inflating: photo_jpg/6ecc2d49cf.jpg
#   inflating: photo_jpg/6ed8cb6c73.jpg
#   inflating: photo_jpg/6edee61a9e.jpg
#   inflating: photo_jpg/6ee301dfa6.jpg
#   inflating: photo_jpg/6ee4e3cfa0.jpg
#   inflating: photo_jpg/6ee582ddd3.jpg
#   inflating: photo_jpg/6ef0e038c4.jpg
#   inflating: photo_jpg/6efbef83a2.jpg
#   inflating: photo_jpg/6f28a81391.jpg
#   inflating: photo_jpg/6f2bf952a9.jpg
#   inflating: photo_jpg/6f40f67816.jpg
#   inflating: photo_jpg/6f48326e10.jpg
#   inflating: photo_jpg/6f48f32192.jpg
#   inflating: photo_jpg/6f5bf1e36c.jpg
#   inflating: photo_jpg/6f5ef8ad57.jpg
#   inflating: photo_jpg/6f68219972.jpg
#   inflating: photo_jpg/6f6d82abff.jpg
#   inflating: photo_jpg/6f7564d1a0.jpg
#   inflating: photo_jpg/6f77237bfc.jpg
#   inflating: photo_jpg/6f8cb591c0.jpg
#   inflating: photo_jpg/6f8d0b8187.jpg
#   inflating: photo_jpg/6f8e3c9a8b.jpg
#   inflating: photo_jpg/6f923ef327.jpg
#   inflating: photo_jpg/6f947d7eac.jpg
#   inflating: photo_jpg/6fadc7344f.jpg
#   inflating: photo_jpg/6fc20169b5.jpg
#   inflating: photo_jpg/6fc42ec979.jpg
#   inflating: photo_jpg/6fc6fa664f.jpg
#   inflating: photo_jpg/6fd27b0261.jpg
#   inflating: photo_jpg/6fd58bb7ed.jpg
#   inflating: photo_jpg/6fd674c2bc.jpg
#   inflating: photo_jpg/6feaf858bb.jpg
#   inflating: photo_jpg/6ff650cc01.jpg
#   inflating: photo_jpg/6ff926036b.jpg
#   inflating: photo_jpg/7007638c04.jpg
#   inflating: photo_jpg/7018cf5472.jpg
#   inflating: photo_jpg/7023e05153.jpg
#   inflating: photo_jpg/7041df8f8d.jpg
#   inflating: photo_jpg/7048682787.jpg
#   inflating: photo_jpg/7056c4d0c9.jpg
#   inflating: photo_jpg/7058938d2d.jpg
#   inflating: photo_jpg/70688893ff.jpg
#   inflating: photo_jpg/7095de0c05.jpg
#   inflating: photo_jpg/709c87be1e.jpg
#   inflating: photo_jpg/70a6584991.jpg
#   inflating: photo_jpg/70adc33191.jpg
#   inflating: photo_jpg/70b1293521.jpg
#   inflating: photo_jpg/70bbdc328b.jpg
#   inflating: photo_jpg/70bfad4fb3.jpg
#   inflating: photo_jpg/70c35d97fa.jpg
#   inflating: photo_jpg/70c4ba13c5.jpg
#   inflating: photo_jpg/70c5926990.jpg
#   inflating: photo_jpg/70d01a9f18.jpg
#   inflating: photo_jpg/70d2dd3347.jpg
#   inflating: photo_jpg/70e1a9d5d0.jpg
#   inflating: photo_jpg/70f83908f4.jpg
#   inflating: photo_jpg/710afec54e.jpg
#   inflating: photo_jpg/710dddaa53.jpg
#   inflating: photo_jpg/710ff8d371.jpg
#   inflating: photo_jpg/711bdf7e70.jpg
#   inflating: photo_jpg/711e41a40a.jpg
#   inflating: photo_jpg/7124e69590.jpg
#   inflating: photo_jpg/7128cb2ee3.jpg
#   inflating: photo_jpg/7140fb929c.jpg
#   inflating: photo_jpg/714de5bcda.jpg
#   inflating: photo_jpg/716437e0a0.jpg
#   inflating: photo_jpg/71697466d8.jpg
#   inflating: photo_jpg/716981b92d.jpg
#   inflating: photo_jpg/717bc1fc72.jpg
#   inflating: photo_jpg/718b15a998.jpg
#   inflating: photo_jpg/71990c1992.jpg
#   inflating: photo_jpg/71a1688eec.jpg
#   inflating: photo_jpg/71ab7757d1.jpg
#   inflating: photo_jpg/71b9dfc246.jpg
#   inflating: photo_jpg/71c9f21e69.jpg
#   inflating: photo_jpg/71cd818b43.jpg
#   inflating: photo_jpg/71cde4e6b9.jpg
#   inflating: photo_jpg/71d0f6d808.jpg
#   inflating: photo_jpg/71d92823a7.jpg
#   inflating: photo_jpg/71e2160bc2.jpg
#   inflating: photo_jpg/71eb79bec9.jpg
#   inflating: photo_jpg/71f375fd61.jpg
#   inflating: photo_jpg/71f38526e3.jpg
#   inflating: photo_jpg/71f84e59d9.jpg
#   inflating: photo_jpg/71fbc6fd17.jpg
#   inflating: photo_jpg/71feaf01d5.jpg
#   inflating: photo_jpg/720358ea9a.jpg
#   inflating: photo_jpg/7207f4dfb5.jpg
#   inflating: photo_jpg/720b03538d.jpg
#   inflating: photo_jpg/720b65616c.jpg
#   inflating: photo_jpg/720b79fcc2.jpg
#   inflating: photo_jpg/721f26a1d5.jpg
#   inflating: photo_jpg/721fb86cc5.jpg
#   inflating: photo_jpg/7226160b9d.jpg
#   inflating: photo_jpg/722cb1e56d.jpg
#   inflating: photo_jpg/7232765c25.jpg
#   inflating: photo_jpg/723451df4f.jpg
#   inflating: photo_jpg/7234b91e34.jpg
#   inflating: photo_jpg/7237fc1604.jpg
#   inflating: photo_jpg/723d373aa3.jpg
#   inflating: photo_jpg/7241d2c3d9.jpg
#   inflating: photo_jpg/7261ec35d2.jpg
#   inflating: photo_jpg/72669a9943.jpg
#   inflating: photo_jpg/72812baf6e.jpg
#   inflating: photo_jpg/7283cfab05.jpg
#   inflating: photo_jpg/728ea2432b.jpg
#   inflating: photo_jpg/7293694fa1.jpg
#   inflating: photo_jpg/72984fac2b.jpg
#   inflating: photo_jpg/72a4736675.jpg
#   inflating: photo_jpg/72a601d8f0.jpg
#   inflating: photo_jpg/72c7727920.jpg
#   inflating: photo_jpg/72d3a41349.jpg
#   inflating: photo_jpg/72d466fe84.jpg
#   inflating: photo_jpg/72e16d5fbd.jpg
#   inflating: photo_jpg/72e448ba0d.jpg
#   inflating: photo_jpg/72f617be7d.jpg
#   inflating: photo_jpg/730f4d3c17.jpg
#   inflating: photo_jpg/7310d880f1.jpg
#   inflating: photo_jpg/731ebe59e9.jpg
#   inflating: photo_jpg/73222f682f.jpg
#   inflating: photo_jpg/73256f9bc4.jpg
#   inflating: photo_jpg/7325a1d7d0.jpg
#   inflating: photo_jpg/732a9c8c6b.jpg
#   inflating: photo_jpg/732becb4d6.jpg
#   inflating: photo_jpg/7333f63f5c.jpg
#   inflating: photo_jpg/7336afe63d.jpg
# ...
#   inflating: photo_jpg/f2a3dc33fe.jpg
#   inflating: photo_jpg/f2b162e74b.jpg
#   inflating: photo_jpg/f2b7c12b9c.jpg
#   inflating: photo_jpg/f2d042180c.jpg
#   inflating: photo_jpg/f2d2d4efbc.jpg
#   inflating: photo_jpg/f2d986db88.jpg
#   inflating: photo_jpg/f2f09c8f41.jpg
#   inflating: photo_jpg/f2f56add24.jpg
#   inflating: photo_jpg/f30e44407b.jpg
#   inflating: photo_jpg/f31217f986.jpg
#   inflating: photo_jpg/f3141801d8.jpg
#   inflating: photo_jpg/f3230db890.jpg
#   inflating: photo_jpg/f32a18c7c6.jpg
#   inflating: photo_jpg/f3356114c7.jpg
#   inflating: photo_jpg/f351ce3bc5.jpg
#   inflating: photo_jpg/f352a7a312.jpg
#   inflating: photo_jpg/f354013389.jpg
#   inflating: photo_jpg/f357fe1f0d.jpg
#   inflating: photo_jpg/f36fc36903.jpg
#   inflating: photo_jpg/f376a8789c.jpg
#   inflating: photo_jpg/f37a93cd01.jpg
#   inflating: photo_jpg/f384c39cd3.jpg
#   inflating: photo_jpg/f3b5806412.jpg
#   inflating: photo_jpg/f3bf66740a.jpg
#   inflating: photo_jpg/f3c61a9a05.jpg
#   inflating: photo_jpg/f3c8ec10ae.jpg
#   inflating: photo_jpg/f3d15e5226.jpg
#   inflating: photo_jpg/f3d86d0bdc.jpg
#   inflating: photo_jpg/f3e4ae010d.jpg
#   inflating: photo_jpg/f3e54bc081.jpg
#   inflating: photo_jpg/f3e9866cb8.jpg
#   inflating: photo_jpg/f3ec3e874d.jpg
#   inflating: photo_jpg/f3ecb32509.jpg
#   inflating: photo_jpg/f3ee6c1af3.jpg
#   inflating: photo_jpg/f3fa90a191.jpg
#   inflating: photo_jpg/f405d9a44e.jpg
#   inflating: photo_jpg/f40af60ddc.jpg
#   inflating: photo_jpg/f40b429650.jpg
#   inflating: photo_jpg/f40b719930.jpg
#   inflating: photo_jpg/f40d9b8368.jpg
#   inflating: photo_jpg/f417a4cc39.jpg
#   inflating: photo_jpg/f41b5dec17.jpg
#   inflating: photo_jpg/f41d5c2163.jpg
#   inflating: photo_jpg/f4219a5e81.jpg
#   inflating: photo_jpg/f42f6f0197.jpg
#   inflating: photo_jpg/f43113c91b.jpg
#   inflating: photo_jpg/f43c6fb1de.jpg
#   inflating: photo_jpg/f44a3275c9.jpg
#   inflating: photo_jpg/f46478e139.jpg
#   inflating: photo_jpg/f46cfb67bd.jpg
#   inflating: photo_jpg/f482274abc.jpg
#   inflating: photo_jpg/f4831ea6fb.jpg
#   inflating: photo_jpg/f4919d3664.jpg
#   inflating: photo_jpg/f494688de8.jpg
#   inflating: photo_jpg/f49ca09b7a.jpg
#   inflating: photo_jpg/f4a6936ec9.jpg
#   inflating: photo_jpg/f4a9c6100f.jpg
#   inflating: photo_jpg/f4c509ad69.jpg
#   inflating: photo_jpg/f4cdc8fdbc.jpg
#   inflating: photo_jpg/f4dd7ea66e.jpg
#   inflating: photo_jpg/f4eb1866c7.jpg
#   inflating: photo_jpg/f4eb47f0dd.jpg
#   inflating: photo_jpg/f501fc4455.jpg
#   inflating: photo_jpg/f51503f974.jpg
#   inflating: photo_jpg/f51f06df8f.jpg
#   inflating: photo_jpg/f53328c040.jpg
#   inflating: photo_jpg/f54cf76011.jpg
#   inflating: photo_jpg/f54dd83443.jpg
#   inflating: photo_jpg/f54f45c2ea.jpg
#   inflating: photo_jpg/f55b066db1.jpg
#   inflating: photo_jpg/f56ae75fdd.jpg
#   inflating: photo_jpg/f56b12cf0b.jpg
#   inflating: photo_jpg/f575a81ad6.jpg
#   inflating: photo_jpg/f58ec475cf.jpg
#   inflating: photo_jpg/f5b336d512.jpg
#   inflating: photo_jpg/f5b3c7c78c.jpg
#   inflating: photo_jpg/f5c1d6af2a.jpg
#   inflating: photo_jpg/f5c3514cca.jpg
#   inflating: photo_jpg/f5c7a8068c.jpg
#   inflating: photo_jpg/f5d163add7.jpg
#   inflating: photo_jpg/f5d1922ba9.jpg
#   inflating: photo_jpg/f5d652e997.jpg
#   inflating: photo_jpg/f5ddf6d767.jpg
#   inflating: photo_jpg/f5efcc2979.jpg
#   inflating: photo_jpg/f5f34241cc.jpg
#   inflating: photo_jpg/f5ffe2e92d.jpg
#   inflating: photo_jpg/f604e3e7e5.jpg
#   inflating: photo_jpg/f607a14dd9.jpg
#   inflating: photo_jpg/f6084689ed.jpg
#   inflating: photo_jpg/f60910ed40.jpg
#   inflating: photo_jpg/f60b4c4d98.jpg
#   inflating: photo_jpg/f60b67ae6e.jpg
#   inflating: photo_jpg/f62bb41c9c.jpg
#   inflating: photo_jpg/f633c4ebed.jpg
#   inflating: photo_jpg/f639ee968c.jpg
#   inflating: photo_jpg/f63a1042f4.jpg
#   inflating: photo_jpg/f63a2b4fb9.jpg
#   inflating: photo_jpg/f64019e49d.jpg
#   inflating: photo_jpg/f647ce5fd1.jpg
#   inflating: photo_jpg/f651e57596.jpg
#   inflating: photo_jpg/f6574b10b7.jpg
#   inflating: photo_jpg/f6626c86e1.jpg
#   inflating: photo_jpg/f6798eb074.jpg
#   inflating: photo_jpg/f67f1708b6.jpg
#   inflating: photo_jpg/f68dae168d.jpg
#   inflating: photo_jpg/f68dcc7a8a.jpg
#   inflating: photo_jpg/f68e29bd81.jpg
#   inflating: photo_jpg/f690980765.jpg
#   inflating: photo_jpg/f69731b55b.jpg
#   inflating: photo_jpg/f69ff9b62b.jpg
#   inflating: photo_jpg/f6aa1d5154.jpg
#   inflating: photo_jpg/f6ab953224.jpg
#   inflating: photo_jpg/f6b61559e0.jpg
#   inflating: photo_jpg/f6ca69a495.jpg
#   inflating: photo_jpg/f6cb2948da.jpg
#   inflating: photo_jpg/f6d01357b6.jpg
#   inflating: photo_jpg/f6e17b1a2a.jpg
#   inflating: photo_jpg/f6e422b697.jpg
#   inflating: photo_jpg/f6e5895253.jpg
#   inflating: photo_jpg/f6e822d131.jpg
#   inflating: photo_jpg/f6e8f07d9d.jpg
#   inflating: photo_jpg/f6efddda9c.jpg
#   inflating: photo_jpg/f706c0860d.jpg
#   inflating: photo_jpg/f70871846a.jpg
#   inflating: photo_jpg/f71cc4d572.jpg
#   inflating: photo_jpg/f721bb7f6d.jpg
#   inflating: photo_jpg/f743f3bf62.jpg
#   inflating: photo_jpg/f74cdcd632.jpg
#   inflating: photo_jpg/f7531c3b99.jpg
#   inflating: photo_jpg/f75a997bb8.jpg
#   inflating: photo_jpg/f76e1ec9a3.jpg
#   inflating: photo_jpg/f771e1e1b0.jpg
#   inflating: photo_jpg/f77377bd03.jpg
#   inflating: photo_jpg/f77505c83f.jpg
#   inflating: photo_jpg/f77c59acb3.jpg
#   inflating: photo_jpg/f77e3cb703.jpg
#   inflating: photo_jpg/f77f395731.jpg
#   inflating: photo_jpg/f790a14012.jpg
#   inflating: photo_jpg/f79d9de05d.jpg
#   inflating: photo_jpg/f7a011547d.jpg
#   inflating: photo_jpg/f7a821c3c8.jpg
#   inflating: photo_jpg/f7ae6e1d31.jpg
#   inflating: photo_jpg/f7c4d8033d.jpg
#   inflating: photo_jpg/f7c78a4eef.jpg
#   inflating: photo_jpg/f7d0dba843.jpg
#   inflating: photo_jpg/f7d0f59566.jpg
#   inflating: photo_jpg/f7d17e77d6.jpg
#   inflating: photo_jpg/f7dbdb551f.jpg
#   inflating: photo_jpg/f7dc666b50.jpg
#   inflating: photo_jpg/f7eb84fdb7.jpg
#   inflating: photo_jpg/f7ee2469f6.jpg
#   inflating: photo_jpg/f7f1d58022.jpg
#   inflating: photo_jpg/f807c72b5d.jpg
#   inflating: photo_jpg/f819274637.jpg
#   inflating: photo_jpg/f81b1cc834.jpg
#   inflating: photo_jpg/f82e8c30ac.jpg
#   inflating: photo_jpg/f82fc48ba4.jpg
#   inflating: photo_jpg/f8350e28db.jpg
#   inflating: photo_jpg/f8363ba521.jpg
#   inflating: photo_jpg/f83b161ca3.jpg
#   inflating: photo_jpg/f83e5b4295.jpg
#   inflating: photo_jpg/f843be17f5.jpg
#   inflating: photo_jpg/f84566ed02.jpg
#   inflating: photo_jpg/f84d77a2a6.jpg
#   inflating: photo_jpg/f85694dfe6.jpg
#   inflating: photo_jpg/f86b847b43.jpg
#   inflating: photo_jpg/f876ba92ea.jpg
#   inflating: photo_jpg/f87a1ab16d.jpg
#   inflating: photo_jpg/f87deecaa2.jpg
#   inflating: photo_jpg/f888dde817.jpg
#   inflating: photo_jpg/f8905451b4.jpg
#   inflating: photo_jpg/f895871068.jpg
#   inflating: photo_jpg/f89bc86075.jpg
#   inflating: photo_jpg/f8b6a915a9.jpg
#   inflating: photo_jpg/f8b73f1a33.jpg
#   inflating: photo_jpg/f8c19eaee6.jpg
#   inflating: photo_jpg/f8c63eea5a.jpg
#   inflating: photo_jpg/f8c8e456d7.jpg
#   inflating: photo_jpg/f8ca80aebb.jpg
#   inflating: photo_jpg/f8e10ef432.jpg
#   inflating: photo_jpg/f8e488ce75.jpg
#   inflating: photo_jpg/f8e6d9f481.jpg
#   inflating: photo_jpg/f8f04744fd.jpg
#   inflating: photo_jpg/f8f98ae176.jpg
#   inflating: photo_jpg/f8fac4e7ff.jpg
#   inflating: photo_jpg/f8ffd3ed06.jpg
#   inflating: photo_jpg/f901dfad23.jpg
#   inflating: photo_jpg/f904d3484c.jpg
#   inflating: photo_jpg/f9080ec43b.jpg
#   inflating: photo_jpg/f90edb8380.jpg
#   inflating: photo_jpg/f90ee2b0db.jpg
#   inflating: photo_jpg/f9151bda3c.jpg
#   inflating: photo_jpg/f917b1c32a.jpg
#   inflating: photo_jpg/f91c3d1f53.jpg
#   inflating: photo_jpg/f91eb42b36.jpg
#   inflating: photo_jpg/f930392388.jpg
#   inflating: photo_jpg/f942443b5d.jpg
#   inflating: photo_jpg/f954a8be77.jpg
#   inflating: photo_jpg/f969505f84.jpg
#   inflating: photo_jpg/f96a50841d.jpg
#   inflating: photo_jpg/f97072faf8.jpg
#   inflating: photo_jpg/f975a1e01e.jpg
#   inflating: photo_jpg/f982a98853.jpg
#   inflating: photo_jpg/f9843ad01b.jpg
#   inflating: photo_jpg/f98627c542.jpg
#   inflating: photo_jpg/f9867ce748.jpg
#   inflating: photo_jpg/f9989c2bd5.jpg
#   inflating: photo_jpg/f99a7a3267.jpg
#   inflating: photo_jpg/f99f52c7f5.jpg
#   inflating: photo_jpg/f99fe506ed.jpg
#   inflating: photo_jpg/f9a20c7988.jpg
#   inflating: photo_jpg/f9b4495f70.jpg
#   inflating: photo_jpg/f9b4d017a3.jpg
#   inflating: photo_jpg/f9ba7b025e.jpg
#   inflating: photo_jpg/f9c9afcd78.jpg
#   inflating: photo_jpg/f9cd461b5e.jpg
#   inflating: photo_jpg/f9cf6e7e27.jpg
#   inflating: photo_jpg/f9e8571801.jpg
#   inflating: photo_jpg/f9f59d905c.jpg
#   inflating: photo_jpg/f9f6bc6871.jpg
#   inflating: photo_jpg/fa0fde7844.jpg
#   inflating: photo_jpg/fa24240abc.jpg
#   inflating: photo_jpg/fa307775e7.jpg
#   inflating: photo_jpg/fa3aba5483.jpg
#   inflating: photo_jpg/fa423fe5a3.jpg
#   inflating: photo_jpg/fa428459e2.jpg
#   inflating: photo_jpg/fa4326ff01.jpg
#   inflating: photo_jpg/fa47656f02.jpg
#   inflating: photo_jpg/fa48b1ceb5.jpg
#   inflating: photo_jpg/fa60f9a0c9.jpg
#   inflating: photo_jpg/fa63566e6e.jpg
#   inflating: photo_jpg/fa728d214f.jpg
#   inflating: photo_jpg/fa751def39.jpg
#   inflating: photo_jpg/fa9a74e9a4.jpg
#   inflating: photo_jpg/fa9a768c9b.jpg
#   inflating: photo_jpg/faa4f82b52.jpg
#   inflating: photo_jpg/faaab4fb19.jpg
#   inflating: photo_jpg/fac89a2440.jpg
#   inflating: photo_jpg/facc9d2df2.jpg
#   inflating: photo_jpg/fad67f0f19.jpg
#   inflating: photo_jpg/fb1779d922.jpg
#   inflating: photo_jpg/fb24316c57.jpg
#   inflating: photo_jpg/fb2a6a49d7.jpg
#   inflating: photo_jpg/fb362a6660.jpg
#   inflating: photo_jpg/fb3676a875.jpg
#   inflating: photo_jpg/fb546829cb.jpg
#   inflating: photo_jpg/fb562cd56b.jpg
#   inflating: photo_jpg/fb73e20575.jpg
#   inflating: photo_jpg/fb755692ce.jpg
#   inflating: photo_jpg/fb85264917.jpg
#   inflating: photo_jpg/fb8fb9b7c8.jpg
#   inflating: photo_jpg/fb97febc5f.jpg
#   inflating: photo_jpg/fb9c5403b8.jpg
#   inflating: photo_jpg/fbaa1647e7.jpg
#   inflating: photo_jpg/fbb5f72776.jpg
#   inflating: photo_jpg/fbb8e36b1c.jpg
#   inflating: photo_jpg/fbb8e5f081.jpg
#   inflating: photo_jpg/fbc1c4e45b.jpg
#   inflating: photo_jpg/fbc34e93dc.jpg
#   inflating: photo_jpg/fbc3754be3.jpg
#   inflating: photo_jpg/fbc70f973a.jpg
#   inflating: photo_jpg/fbdaf94ace.jpg
#   inflating: photo_jpg/fbf3ab42e9.jpg
#   inflating: photo_jpg/fc02616c06.jpg
#   inflating: photo_jpg/fc043d38eb.jpg
#   inflating: photo_jpg/fc04ed2d42.jpg
#   inflating: photo_jpg/fc075619e7.jpg
#   inflating: photo_jpg/fc16c59788.jpg
#   inflating: photo_jpg/fc30e458d6.jpg
#   inflating: photo_jpg/fc458d4ee1.jpg
#   inflating: photo_jpg/fc49fb17f3.jpg
#   inflating: photo_jpg/fc51c26e2d.jpg
#   inflating: photo_jpg/fc59b308a8.jpg
#   inflating: photo_jpg/fc5feebdc8.jpg
#   inflating: photo_jpg/fc622b5577.jpg
#   inflating: photo_jpg/fc64e9fe13.jpg
#   inflating: photo_jpg/fc6d47c7b0.jpg
#   inflating: photo_jpg/fc9d809645.jpg
#   inflating: photo_jpg/fcaeb2fb17.jpg
#   inflating: photo_jpg/fcc0dc41b3.jpg
#   inflating: photo_jpg/fcc59cb31d.jpg
#   inflating: photo_jpg/fcd35ead6e.jpg
#   inflating: photo_jpg/fcd5eaceb7.jpg
#   inflating: photo_jpg/fcdd5b1e31.jpg
#   inflating: photo_jpg/fce074b92c.jpg
#   inflating: photo_jpg/fd0071794a.jpg
#   inflating: photo_jpg/fd06d4e7e3.jpg
#   inflating: photo_jpg/fd0a02921a.jpg
#   inflating: photo_jpg/fd15f29d57.jpg
#   inflating: photo_jpg/fd1f9293ca.jpg
#   inflating: photo_jpg/fd20b4c41a.jpg
#   inflating: photo_jpg/fd457c68d9.jpg
#   inflating: photo_jpg/fd48eb1f90.jpg
#   inflating: photo_jpg/fd49936788.jpg
#   inflating: photo_jpg/fd4debe229.jpg
#   inflating: photo_jpg/fd541f5f93.jpg
#   inflating: photo_jpg/fd5ce86649.jpg
#   inflating: photo_jpg/fd619e77af.jpg
#   inflating: photo_jpg/fd6b68436e.jpg
#   inflating: photo_jpg/fd6c9bcbfa.jpg
#   inflating: photo_jpg/fd7d170a69.jpg
#   inflating: photo_jpg/fd85d15361.jpg
#   inflating: photo_jpg/fd8c99d93b.jpg
#   inflating: photo_jpg/fd9767f897.jpg
#   inflating: photo_jpg/fda550148e.jpg
#   inflating: photo_jpg/fdad36c1e0.jpg
#   inflating: photo_jpg/fdb01f9aba.jpg
#   inflating: photo_jpg/fdb031e406.jpg
#   inflating: photo_jpg/fdc2b3b936.jpg
#   inflating: photo_jpg/fdc6c88003.jpg
#   inflating: photo_jpg/fdce0c0d6d.jpg
#   inflating: photo_jpg/fdd33c1145.jpg
#   inflating: photo_jpg/fddc60bb99.jpg
#   inflating: photo_jpg/fddcadfd3a.jpg
#   inflating: photo_jpg/fde289be21.jpg
#   inflating: photo_jpg/fde28fae2a.jpg
#   inflating: photo_jpg/fde46f2be4.jpg
#   inflating: photo_jpg/fdf013342c.jpg
#   inflating: photo_jpg/fdf57fbe60.jpg
#   inflating: photo_jpg/fdf84c4887.jpg
#   inflating: photo_jpg/fdfc86a000.jpg
#   inflating: photo_jpg/fe00c3d087.jpg
#   inflating: photo_jpg/fe0a4f0e5a.jpg
#   inflating: photo_jpg/fe1561993e.jpg
#   inflating: photo_jpg/fe1c9d9e5a.jpg
#   inflating: photo_jpg/fe283d4ae3.jpg
#   inflating: photo_jpg/fe381a7c17.jpg
#   inflating: photo_jpg/fe3c9d0016.jpg
#   inflating: photo_jpg/fe3de96780.jpg
#   inflating: photo_jpg/fe3feb7d1b.jpg
#   inflating: photo_jpg/fe40ac1d8b.jpg
#   inflating: photo_jpg/fe4c4e4b6b.jpg
#   inflating: photo_jpg/fe5dc7ef05.jpg
#   inflating: photo_jpg/fe6152a619.jpg
#   inflating: photo_jpg/fe65abaafd.jpg
#   inflating: photo_jpg/fe702a794e.jpg
#   inflating: photo_jpg/fe714c846e.jpg
#   inflating: photo_jpg/fe7af9c427.jpg
#   inflating: photo_jpg/fe9cc12ae1.jpg
#   inflating: photo_jpg/fea227771f.jpg
#   inflating: photo_jpg/fea42e4505.jpg
#   inflating: photo_jpg/fea4d4f76c.jpg
#   inflating: photo_jpg/fea5afe679.jpg
#   inflating: photo_jpg/feb132e4c1.jpg
#   inflating: photo_jpg/fee0c39907.jpg
#   inflating: photo_jpg/fefb86c469.jpg
#   inflating: photo_jpg/fefcd07a5e.jpg
#   inflating: photo_jpg/ff03c98f0e.jpg
#   inflating: photo_jpg/ff2152ac2a.jpg
#   inflating: photo_jpg/ff258e79ce.jpg
#   inflating: photo_jpg/ff2cb6658c.jpg
#   inflating: photo_jpg/ff2f57429f.jpg
#   inflating: photo_jpg/ff3867d938.jpg
#   inflating: photo_jpg/ff46474c6d.jpg
#   inflating: photo_jpg/ff48e8580b.jpg
#   inflating: photo_jpg/ff58af0f3b.jpg
#   inflating: photo_jpg/ff5c15ab50.jpg
#   inflating: photo_jpg/ff6ed45562.jpg
#   inflating: photo_jpg/ff757d7db3.jpg
#   inflating: photo_jpg/ff769c35c9.jpg
#   inflating: photo_jpg/ff7d83bc1d.jpg
#   inflating: photo_jpg/ff853f993b.jpg
#   inflating: photo_jpg/ff9ca0e1bb.jpg
#   inflating: photo_jpg/ff9e94857b.jpg
#   inflating: photo_jpg/ffa1ee4875.jpg
#   inflating: photo_jpg/ffa5d376be.jpg
#   inflating: photo_jpg/ffbbb24b43.jpg
#   inflating: photo_jpg/ffbdd43bfb.jpg
#   inflating: photo_jpg/ffc5b52a77.jpg
#   inflating: photo_jpg/ffcc20463a.jpg
#   inflating: photo_jpg/ffcdd249dd.jpg
#   inflating: photo_jpg/ffcf64f150.jpg
#   inflating: photo_jpg/ffd71fce61.jpg
#   inflating: photo_jpg/ffe1af8ca0.jpg
#   inflating: photo_jpg/fff5c33050.jpg
#   inflating: photo_jpg/fffaaaae65.jpg
#   inflating: photo_jpg/fffc0836d7.jpg
#   inflating: photo_tfrec/photo00-352.tfrec
#   inflating: photo_tfrec/photo01-352.tfrec
#   inflating: photo_tfrec/photo02-352.tfrec
#   inflating: photo_tfrec/photo03-352.tfrec
#   inflating: photo_tfrec/photo04-352.tfrec
#   inflating: photo_tfrec/photo05-352.tfrec
#   inflating: photo_tfrec/photo06-352.tfrec
#   inflating: photo_tfrec/photo07-352.tfrec
#   inflating: photo_tfrec/photo08-352.tfrec
#   inflating: photo_tfrec/photo09-352.tfrec
#   inflating: photo_tfrec/photo10-352.tfrec
#   inflating: photo_tfrec/photo11-352.tfrec
#   inflating: photo_tfrec/photo12-352.tfrec
#   inflating: photo_tfrec/photo13-352.tfrec
#   inflating: photo_tfrec/photo14-352.tfrec
#   inflating: photo_tfrec/photo15-352.tfrec
#   inflating: photo_tfrec/photo16-352.tfrec
#   inflating: photo_tfrec/photo17-352.tfrec
#   inflating: photo_tfrec/photo18-352.tfrec
#   inflating: photo_tfrec/photo19-350.tfrec

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
import pandas as pd
import torch as torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
import random
import os
import time
from skimage import io, color, filters
import zipfile
from PIL import Image
from tqdm import tqdm
import wandb
from torchsummary import summary
import io
from contextlib import redirect_stdout

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
BATCH_SIZE = 1
EPOCHS = 30

# %% [markdown]
# # Save and Load

# %%
def load_checkpoint(ckpt_path, map_location=None):
    ckpt = torch.load(ckpt_path, map_location=map_location)
    print(' [*] Loading checkpoint from %s succeed!' % ckpt_path)
    return ckpt

# %%
def save_checkpoint(state, save_path):
    torch.save(state, save_path)

# %% [markdown]
# # Data

# %%
dataset_path = ""

# List all image files in the dataset directory
photo_dir = os.path.join(dataset_path, "photo_jpg")
monet_dir = os.path.join(dataset_path, "monet_jpg")
photo_files = [os.path.join(photo_dir, file) for file in os.listdir(photo_dir) if file.endswith(('.jpg'))]
monet_files = [os.path.join(monet_dir, file) for file in os.listdir(monet_dir) if file.endswith(('.jpg'))]

# Create a pandas DataFrame with the image file paths
photo_df = pd.DataFrame({'image_path': photo_files})
monet_df = pd.DataFrame({'image_path': monet_files})

photo_df.head(), monet_df.head()
# Out:
# (                 image_path
#  0  photo_jpg/9f98b589a1.jpg
#  1  photo_jpg/0723d52098.jpg
#  2  photo_jpg/72d466fe84.jpg
#  3  photo_jpg/277d120bb4.jpg
#  4  photo_jpg/47100a9939.jpg,
#                   image_path
#  0  monet_jpg/a202b1b200.jpg
#  1  monet_jpg/7239ba0b55.jpg
#  2  monet_jpg/599098859e.jpg
#  3  monet_jpg/3deea9f4a4.jpg
#  4  monet_jpg/eb3cc5c559.jpg)

# %%
photo_examples = photo_df.sample(n=5)
monet_examples = monet_df.sample(n=5)

photo_examples_images = [Image.open(path) for path in photo_examples['image_path']]
monet_examples_images = [Image.open(path) for path in monet_examples['image_path']]

all_images = photo_examples_images + monet_examples_images

titles = [f'Photo {i+1}' for i in range(5)] + \
         [f'Monet {i+1}' for i in range(5)]

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(15, 6))
axes = axes.flatten()

for i, (img, title) in enumerate(zip(all_images, titles)):
    axes[i].imshow(img)
    axes[i].set_title(title, fontsize=10)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
class ImageDataset(Dataset):
  def __init__(
    self,
    monet_dir, photo_dir,
    size=(256, 256),
    normalize=True,
    augment=False,
    ):
    super().__init__()
    self.monet_dir = monet_dir
    self.photo_dir = photo_dir
    self.monet_idx = dict()
    self.photo_idx = dict()
    self.augment = augment

    base_transforms = [transforms.Resize(size)]

    if augment:
        augment_transforms = [
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        ]
        base_transforms.extend(augment_transforms)

    base_transforms.append(transforms.ToTensor())
    if normalize:
        base_transforms.append(transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)))

    self.transform = transforms.Compose(base_transforms)

    for i, fl in enumerate(os.listdir(self.monet_dir)):
      self.monet_idx[i] = fl
    for i, fl in enumerate(os.listdir(self.photo_dir)):
      self.photo_idx[i] = fl
    self.len = min(len(self.monet_idx.keys()), len(self.photo_idx.keys()))

  def __getitem__(self, idx):
    rand_idx = int(np.random.uniform(0, self.len))
    photo_path = os.path.join(self.photo_dir, self.photo_idx[idx])
    monet_path = os.path.join(self.monet_dir, self.monet_idx[rand_idx])
    photo_img = Image.open(photo_path)
    monet_img = Image.open(monet_path)

    if self.augment:
        rand_state = torch.get_rng_state()
        photo_img = self.transform(photo_img)
        torch.set_rng_state(rand_state)
        monet_img = self.transform(monet_img)
    else:
        photo_img = self.transform(photo_img)
        monet_img = self.transform(monet_img)

    return photo_img, monet_img

  def __len__(self):
    return self.len

# %%
img_ds = ImageDataset(monet_dir, photo_dir)
img_ds_a = ImageDataset(monet_dir, photo_dir, augment=True)
img_ds[0][0].shape, img_ds[0][1].shape
# Out:
# (torch.Size([3, 256, 256]), torch.Size([3, 256, 256]))

# %%
img_dl = DataLoader(img_ds, batch_size=BATCH_SIZE, shuffle=True)
img_dl_a = DataLoader(img_ds_a, batch_size=BATCH_SIZE, shuffle=True)

# %%
start = 0
val_photos = [img_ds_a[i][0] for i in range(start, start + 3)]

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for i, img in enumerate(val_photos):
    # Unnormalize for display
    img_disp = img.cpu().numpy().transpose(1, 2, 0) * 0.5 + 0.5
    axes[i].imshow(np.clip(img_disp, 0, 1))
    axes[i].axis('off')
    axes[i].set_title(f'Photo {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# ## Blocks

# %% [markdown]
# ### Down Block

# %%
class Downblock(nn.Module):
    def __init__(
        self,
        # dims
        in_ch, out_ch,
        # conv
        kernel_size=3, stride=1, padding=0, use_bias=True,
        # norm
        apply_norm=True, use_inst_norm=True,
        # activation
        activation='relu',
        # dropout
        dropout_ratio=0.0
        ):
        super().__init__()
        layers = []

        # 1. conv (better padding)
        layers.append(nn.ReflectionPad2d(padding))
        layers.append(nn.Conv2d(
            in_ch, out_ch,
            kernel_size, stride, 0,
            bias=use_bias,
            padding_mode='reflect'
        ))

        # 2. norm
        if apply_norm:
            if use_inst_norm:
                layers.append(nn.InstanceNorm2d(out_ch))
            else:
                layers.append(nn.BatchNorm2d(out_ch))

        # 3. activation
        if activation != '':
            if activation == 'gelu':
                layers.append(nn.GELU())
            elif activation == 'leaky':
                layers.append(nn.LeakyReLU(negative_slope=0.2, inplace=True))
            else:
                layers.append(nn.ReLU(inplace=True))

        # 4. dropout
        if dropout_ratio > 0.0:
            layers.append(nn.Dropout(dropout_ratio))

        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Residual Block

# %%
class Resblock(nn.Module):
    def __init__(
        self,
        # dims
        in_features,
        # norm
        use_inst_norm=True,
        # activation
        use_gelu=True,
        # dropout
        dropout_ratio=0.5
        ):
        super().__init__()

        # 1. refl pad + down block (activation + dropout)
        layers = list()
        layers.append(nn.ReflectionPad2d(1))
        layers.append(Downblock(
            in_ch=in_features, out_ch=in_features,
            kernel_size=3, stride=1, padding=0, use_bias=True,
            apply_norm=True, use_inst_norm=use_inst_norm,
            activation='gelu' if use_gelu else 'relu',
            dropout_ratio=dropout_ratio
        ))

        # 2. refl pad + down block
        layers.append(nn.ReflectionPad2d(1))
        layers.append(Downblock(
            in_ch=in_features, out_ch=in_features,
            kernel_size=3, stride=1, padding=0, use_bias=True,
            apply_norm=True, use_inst_norm=use_inst_norm,
            activation='',
            dropout_ratio=0.0
        ))

        self.res = nn.Sequential(*layers)

    def forward(self, x):
        return x + self.res(x)

# %% [markdown]
# ### Up Block

# %%
class Upblock(nn.Module):
    def __init__(
        self,
        # dims
        in_ch, out_ch,
        # conv transpose
        kernel_size=3, stride=2, padding=1, output_padding=1, use_bias=True,
        # norm
        apply_norm=True, use_inst_norm=True,
        # activation
        activation='gelu',
        # dropout
        dropout_ratio=0.5,
        # UNet specific
        is_pre_activation=False
        ):
        super().__init__()
        layers = []

        # 1. conv transpose
        # layers.append(nn.ConvTranspose2d(
        #     in_ch, out_ch,
        #     kernel_size=kernel_size,
        #     stride=stride,
        #     padding=padding,
        #     output_padding=output_padding,
        #     bias=use_bias
        # ))

        # 1. upsample + conv (checkerboard fix)
        layers.append(nn.Upsample(scale_factor=stride, mode='nearest'))
        layers.append(nn.Conv2d(
            in_ch, out_ch,
            kernel_size=kernel_size,
            stride=1,
            padding=padding,
            bias=use_bias
        ))


        # 2. norm
        if apply_norm:
            if use_inst_norm:
                layers.append(nn.InstanceNorm2d(out_ch))
            else:
                layers.append(nn.BatchNorm2d(out_ch))

        # 3. activation
        if activation != '':
            if activation == 'gelu':
                act = nn.GELU()
            else:
                act = nn.ReLU(inplace=True)

            if is_pre_activation:
                layers.insert(1, act)
            else:
                layers.append(act)

        # 4. Dropout
        if dropout_ratio > 0.0:
            layers.append(nn.Dropout(dropout_ratio))

        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Generator

# %% [markdown]
# ### ResNet Based Generator

# %%
class ResNetGenerator(nn.Module):
    def __init__(self, in_ch=3, out_ch=3, n_resblocks=6, dropout=0.5):
        super().__init__()

        model = list()
        model.append(nn.ReflectionPad2d(3))

        # Downsampling
        model.append(Downblock(
            in_ch=in_ch, out_ch=64,
            kernel_size=7, stride=1, padding=0, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='gelu',
            dropout_ratio=0.0
        ))
        model.append(Downblock(
            in_ch=64, out_ch=128,
            kernel_size=3, stride=2, padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='gelu',
            dropout_ratio=0.0
        ))
        model.append(Downblock(
            in_ch=128, out_ch=256,
            kernel_size=3, stride=2, padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='gelu',
            dropout_ratio=0.0
        ))

        # Residual blocks
        for _ in range(n_resblocks):
            model.append(Resblock(
                in_features=256,
                use_inst_norm=True,
                use_gelu=True,
                dropout_ratio=dropout
            ))

        # Upsampling
        model.append(Upblock(
            in_ch=256, out_ch=128,
            kernel_size=3, stride=2, padding=1, output_padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='gelu',
            dropout_ratio=dropout
        ))
        model.append(Upblock(
            in_ch=128, out_ch=64,
            kernel_size=3, stride=2, padding=1, output_padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='gelu',
            dropout_ratio=dropout
        ))
        model.append(nn.ReflectionPad2d(3))
        model.append(nn.Conv2d(64, out_ch, kernel_size=7, stride=1, padding=0))

        # Scale output to [-1, 1]
        model.append(nn.Tanh())

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %%
resnet = ResNetGenerator(3,3).to(device)
summary(resnet, (3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 262, 262]               0
#    ReflectionPad2d-2          [-1, 3, 262, 262]               0
#             Conv2d-3         [-1, 64, 256, 256]           9,472
#     InstanceNorm2d-4         [-1, 64, 256, 256]               0
#               GELU-5         [-1, 64, 256, 256]               0
#          Downblock-6         [-1, 64, 256, 256]               0
#    ReflectionPad2d-7         [-1, 64, 258, 258]               0
#             Conv2d-8        [-1, 128, 128, 128]          73,856
#     InstanceNorm2d-9        [-1, 128, 128, 128]               0
#              GELU-10        [-1, 128, 128, 128]               0
#         Downblock-11        [-1, 128, 128, 128]               0
#   ReflectionPad2d-12        [-1, 128, 130, 130]               0
#            Conv2d-13          [-1, 256, 64, 64]         295,168
#    InstanceNorm2d-14          [-1, 256, 64, 64]               0
#              GELU-15          [-1, 256, 64, 64]               0
#         Downblock-16          [-1, 256, 64, 64]               0
#   ReflectionPad2d-17          [-1, 256, 66, 66]               0
#   ReflectionPad2d-18          [-1, 256, 66, 66]               0
#            Conv2d-19          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-20          [-1, 256, 64, 64]               0
#              GELU-21          [-1, 256, 64, 64]               0
#           Dropout-22          [-1, 256, 64, 64]               0
#         Downblock-23          [-1, 256, 64, 64]               0
#   ReflectionPad2d-24          [-1, 256, 66, 66]               0
#   ReflectionPad2d-25          [-1, 256, 66, 66]               0
#            Conv2d-26          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-27          [-1, 256, 64, 64]               0
#         Downblock-28          [-1, 256, 64, 64]               0
#          Resblock-29          [-1, 256, 64, 64]               0
#   ReflectionPad2d-30          [-1, 256, 66, 66]               0
#   ReflectionPad2d-31          [-1, 256, 66, 66]               0
#            Conv2d-32          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-33          [-1, 256, 64, 64]               0
#              GELU-34          [-1, 256, 64, 64]               0
#           Dropout-35          [-1, 256, 64, 64]               0
#         Downblock-36          [-1, 256, 64, 64]               0
#   ReflectionPad2d-37          [-1, 256, 66, 66]               0
#   ReflectionPad2d-38          [-1, 256, 66, 66]               0
#            Conv2d-39          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-40          [-1, 256, 64, 64]               0
#         Downblock-41          [-1, 256, 64, 64]               0
#          Resblock-42          [-1, 256, 64, 64]               0
#   ReflectionPad2d-43          [-1, 256, 66, 66]               0
#   ReflectionPad2d-44          [-1, 256, 66, 66]               0
#            Conv2d-45          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-46          [-1, 256, 64, 64]               0
#              GELU-47          [-1, 256, 64, 64]               0
#           Dropout-48          [-1, 256, 64, 64]               0
#         Downblock-49          [-1, 256, 64, 64]               0
#   ReflectionPad2d-50          [-1, 256, 66, 66]               0
#   ReflectionPad2d-51          [-1, 256, 66, 66]               0
#            Conv2d-52          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-53          [-1, 256, 64, 64]               0
#         Downblock-54          [-1, 256, 64, 64]               0
#          Resblock-55          [-1, 256, 64, 64]               0
#   ReflectionPad2d-56          [-1, 256, 66, 66]               0
#   ReflectionPad2d-57          [-1, 256, 66, 66]               0
#            Conv2d-58          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-59          [-1, 256, 64, 64]               0
#              GELU-60          [-1, 256, 64, 64]               0
#           Dropout-61          [-1, 256, 64, 64]               0
#         Downblock-62          [-1, 256, 64, 64]               0
#   ReflectionPad2d-63          [-1, 256, 66, 66]               0
#   ReflectionPad2d-64          [-1, 256, 66, 66]               0
#            Conv2d-65          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-66          [-1, 256, 64, 64]               0
#         Downblock-67          [-1, 256, 64, 64]               0
#          Resblock-68          [-1, 256, 64, 64]               0
#   ReflectionPad2d-69          [-1, 256, 66, 66]               0
#   ReflectionPad2d-70          [-1, 256, 66, 66]               0
#            Conv2d-71          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-72          [-1, 256, 64, 64]               0
#              GELU-73          [-1, 256, 64, 64]               0
#           Dropout-74          [-1, 256, 64, 64]               0
#         Downblock-75          [-1, 256, 64, 64]               0
#   ReflectionPad2d-76          [-1, 256, 66, 66]               0
#   ReflectionPad2d-77          [-1, 256, 66, 66]               0
#            Conv2d-78          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-79          [-1, 256, 64, 64]               0
#         Downblock-80          [-1, 256, 64, 64]               0
#          Resblock-81          [-1, 256, 64, 64]               0
#   ReflectionPad2d-82          [-1, 256, 66, 66]               0
#   ReflectionPad2d-83          [-1, 256, 66, 66]               0
#            Conv2d-84          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-85          [-1, 256, 64, 64]               0
#              GELU-86          [-1, 256, 64, 64]               0
#           Dropout-87          [-1, 256, 64, 64]               0
#         Downblock-88          [-1, 256, 64, 64]               0
#   ReflectionPad2d-89          [-1, 256, 66, 66]               0
#   ReflectionPad2d-90          [-1, 256, 66, 66]               0
#            Conv2d-91          [-1, 256, 64, 64]         590,080
#    InstanceNorm2d-92          [-1, 256, 64, 64]               0
#         Downblock-93          [-1, 256, 64, 64]               0
#          Resblock-94          [-1, 256, 64, 64]               0
#          Upsample-95        [-1, 256, 128, 128]               0
#            Conv2d-96        [-1, 128, 128, 128]         295,040
#    InstanceNorm2d-97        [-1, 128, 128, 128]               0
#              GELU-98        [-1, 128, 128, 128]               0
#           Dropout-99        [-1, 128, 128, 128]               0
#          Upblock-100        [-1, 128, 128, 128]               0
#         Upsample-101        [-1, 128, 256, 256]               0
#           Conv2d-102         [-1, 64, 256, 256]          73,792
#   InstanceNorm2d-103         [-1, 64, 256, 256]               0
#             GELU-104         [-1, 64, 256, 256]               0
#          Dropout-105         [-1, 64, 256, 256]               0
#          Upblock-106         [-1, 64, 256, 256]               0
#  ReflectionPad2d-107         [-1, 64, 262, 262]               0
#           Conv2d-108          [-1, 3, 256, 256]           9,411
#             Tanh-109          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 7,837,699
# Trainable params: 7,837,699
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 1284.85
# Params size (MB): 29.90
# Estimated Total Size (MB): 1315.50
# ----------------------------------------------------------------

# %% [markdown]
# ### U-Net Based Generator

# %%
class UNetGenerator(nn.Module):
    def __init__(self, in_ch=3, out_ch=3, num_downs=7, dropout=0.5):
        super().__init__()

        self.num_downs = num_downs

        base_ch = 64

        # Encoder/Decoder channel progression
        enc_in_chs = [in_ch] + [base_ch * min(2**i, 8) for i in range(num_downs-1)]
        enc_out_chs = [base_ch * min(2**i, 8) for i in range(num_downs)]

        dec_in_chs = [enc_out_chs[::-1][0]] + [c * 2 for c in enc_out_chs[::-1][1:]]
        dec_out_chs = enc_in_chs[::-1]

        # Encoder
        self.encoder = nn.ModuleList()
        for i in range(num_downs):
            use_norm = i > 0 and i < num_downs - 1 # No norm in first layer or last layer (bottleneck)
            activation = 'leaky' if i != num_downs - 1 else 'relu'
            self.encoder.append(
                Downblock(
                    in_ch=enc_in_chs[i], out_ch=enc_out_chs[i],
                    kernel_size=4, stride=2, padding=1, use_bias=False,
                    apply_norm=use_norm, use_inst_norm=True,
                    activation=activation,
                    dropout_ratio=0.0
                )
            )

        # Decoder
        self.decoder = nn.ModuleList()
        for i in range(num_downs):
            use_dropout = i < 3 # First 3 decoder layers have dropout
            apply_norm = i != num_downs - 1 # No norm in final layer
            activation = '' if i == num_downs - 1 else 'relu' # No activation in final layer
            self.decoder.append(
                Upblock(
                    in_ch=dec_in_chs[i], out_ch=dec_out_chs[i],
                    kernel_size=3, stride=2, padding=1, output_padding=0, use_bias=False,
                    apply_norm=apply_norm, use_inst_norm=True,
                    activation=activation,
                    dropout_ratio=dropout if use_dropout else 0.0,
                    is_pre_activation=True
                )
            )

        self.tanh = nn.Tanh()

    def forward(self, x):
        # Encoder output for skip connections
        encoder_outputs = []

        # Encoder forward pass
        current = x
        for encoder_block in self.encoder:
            current = encoder_block(current)
            encoder_outputs.append(current)

        # Decoder forward pass with skip connections
        for i, decoder_block in enumerate(self.decoder):
            current = decoder_block(current)
            skip_idx = len(encoder_outputs) - 1 - i - 1
            if skip_idx >= 0:
                current = torch.cat([current, encoder_outputs[skip_idx]], dim=1)

        # Tanh activation at the end
        output = self.tanh(current)

        return output

# %%
unet = UNetGenerator(3,3).to(device)
summary(unet, (3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 258, 258]               0
#             Conv2d-2         [-1, 64, 128, 128]           3,072
#          LeakyReLU-3         [-1, 64, 128, 128]               0
#          Downblock-4         [-1, 64, 128, 128]               0
#    ReflectionPad2d-5         [-1, 64, 130, 130]               0
#             Conv2d-6          [-1, 128, 64, 64]         131,072
#     InstanceNorm2d-7          [-1, 128, 64, 64]               0
#          LeakyReLU-8          [-1, 128, 64, 64]               0
#          Downblock-9          [-1, 128, 64, 64]               0
#   ReflectionPad2d-10          [-1, 128, 66, 66]               0
#            Conv2d-11          [-1, 256, 32, 32]         524,288
#    InstanceNorm2d-12          [-1, 256, 32, 32]               0
#         LeakyReLU-13          [-1, 256, 32, 32]               0
#         Downblock-14          [-1, 256, 32, 32]               0
#   ReflectionPad2d-15          [-1, 256, 34, 34]               0
#            Conv2d-16          [-1, 512, 16, 16]       2,097,152
#    InstanceNorm2d-17          [-1, 512, 16, 16]               0
#         LeakyReLU-18          [-1, 512, 16, 16]               0
#         Downblock-19          [-1, 512, 16, 16]               0
#   ReflectionPad2d-20          [-1, 512, 18, 18]               0
#            Conv2d-21            [-1, 512, 8, 8]       4,194,304
#    InstanceNorm2d-22            [-1, 512, 8, 8]               0
#         LeakyReLU-23            [-1, 512, 8, 8]               0
#         Downblock-24            [-1, 512, 8, 8]               0
#   ReflectionPad2d-25          [-1, 512, 10, 10]               0
#            Conv2d-26            [-1, 512, 4, 4]       4,194,304
#    InstanceNorm2d-27            [-1, 512, 4, 4]               0
#         LeakyReLU-28            [-1, 512, 4, 4]               0
#         Downblock-29            [-1, 512, 4, 4]               0
#   ReflectionPad2d-30            [-1, 512, 6, 6]               0
#            Conv2d-31            [-1, 512, 2, 2]       4,194,304
#              ReLU-32            [-1, 512, 2, 2]               0
#         Downblock-33            [-1, 512, 2, 2]               0
#          Upsample-34            [-1, 512, 4, 4]               0
#              ReLU-35            [-1, 512, 4, 4]               0
#            Conv2d-36            [-1, 512, 4, 4]       2,359,296
#    InstanceNorm2d-37            [-1, 512, 4, 4]               0
#           Dropout-38            [-1, 512, 4, 4]               0
#           Upblock-39            [-1, 512, 4, 4]               0
#          Upsample-40           [-1, 1024, 8, 8]               0
#              ReLU-41           [-1, 1024, 8, 8]               0
#            Conv2d-42            [-1, 512, 8, 8]       4,718,592
#    InstanceNorm2d-43            [-1, 512, 8, 8]               0
#           Dropout-44            [-1, 512, 8, 8]               0
#           Upblock-45            [-1, 512, 8, 8]               0
#          Upsample-46         [-1, 1024, 16, 16]               0
#              ReLU-47         [-1, 1024, 16, 16]               0
#            Conv2d-48          [-1, 512, 16, 16]       4,718,592
#    InstanceNorm2d-49          [-1, 512, 16, 16]               0
#           Dropout-50          [-1, 512, 16, 16]               0
#           Upblock-51          [-1, 512, 16, 16]               0
#          Upsample-52         [-1, 1024, 32, 32]               0
#              ReLU-53         [-1, 1024, 32, 32]               0
#            Conv2d-54          [-1, 256, 32, 32]       2,359,296
#    InstanceNorm2d-55          [-1, 256, 32, 32]               0
#           Upblock-56          [-1, 256, 32, 32]               0
#          Upsample-57          [-1, 512, 64, 64]               0
#              ReLU-58          [-1, 512, 64, 64]               0
#            Conv2d-59          [-1, 128, 64, 64]         589,824
#    InstanceNorm2d-60          [-1, 128, 64, 64]               0
#           Upblock-61          [-1, 128, 64, 64]               0
#          Upsample-62        [-1, 256, 128, 128]               0
#              ReLU-63        [-1, 256, 128, 128]               0
#            Conv2d-64         [-1, 64, 128, 128]         147,456
#    InstanceNorm2d-65         [-1, 64, 128, 128]               0
#           Upblock-66         [-1, 64, 128, 128]               0
#          Upsample-67        [-1, 128, 256, 256]               0
#            Conv2d-68          [-1, 3, 256, 256]           3,456
#           Upblock-69          [-1, 3, 256, 256]               0
#              Tanh-70          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 30,235,008
# Trainable params: 30,235,008
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 304.26
# Params size (MB): 115.34
# Estimated Total Size (MB): 420.34
# ----------------------------------------------------------------

# %% [markdown]
# ## Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_ch=3):
        super().__init__()

        model = list()

        # Downsampling
        model.append(Downblock(
            in_ch=in_ch, out_ch=64,
            kernel_size=4, stride=2, padding=1, use_bias=True,
            apply_norm=False, # no norm in first layer for better stability
            activation='leaky',
            dropout_ratio=0.0
        ))
        model.append(Downblock(
            in_ch=64, out_ch=128,
            kernel_size=4, stride=2, padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='leaky',
            dropout_ratio=0.0
        ))
        model.append(Downblock(
            in_ch=128, out_ch=256,
            kernel_size=4, stride=2, padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='leaky',
            dropout_ratio=0.0
        ))
        model.append(Downblock(
            in_ch=256, out_ch=512,
            kernel_size=4, stride=1, padding=1, use_bias=True,
            apply_norm=True, use_inst_norm=True,
            activation='leaky',
            dropout_ratio=0.0
        ))

        # Output layer
        model.append(nn.Conv2d(
            in_channels=512, out_channels=1,
            kernel_size=4, stride=1, padding=1
        ))

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Adversarial Losses

# %%
class AdversarialLosses:
    def __init__(
        self,
        adversarial_loss_type = 'lsgan' # Options: 'lsgan', 'hinge', 'vanilla'
        ):
        self.adversarial_loss_type = adversarial_loss_type

    def gen_adv_loss(self, fake_pred):
        """Compute adversarial loss for generator based on loss type"""
        if self.adversarial_loss_type == 'lsgan':
            return self.mse_loss(fake_pred, target_is_real=True)
        elif self.adversarial_loss_type == 'hinge':
            return self.hinge_loss_generator(fake_pred)
        elif self.adversarial_loss_type == 'vanilla':
            return self.vanilla_gan_loss(fake_pred, target_is_real=True)
        else:
            raise ValueError(f"Unknown adversarial loss type: {self.adversarial_loss_type}")

    def disc_adv_loss(self, real_pred, fake_pred):
        """Compute adversarial loss for discriminator based on loss type"""
        if self.adversarial_loss_type == 'lsgan':
            real_loss = self.mse_loss(real_pred, target_is_real=True)
            fake_loss = self.mse_loss(fake_pred, target_is_real=False)
            return (real_loss + fake_loss) * 0.5
        elif self.adversarial_loss_type == 'hinge':
            return self.hinge_loss_discriminator(real_pred, fake_pred)
        elif self.adversarial_loss_type == 'vanilla':
            real_loss = self.vanilla_gan_loss(real_pred, target_is_real=True)
            fake_loss = self.vanilla_gan_loss(fake_pred, target_is_real=False)
            return (real_loss + fake_loss) * 0.5
        else:
            raise ValueError(f"Unknown adversarial loss type: {self.adversarial_loss_type}")

    @staticmethod
    def mse_loss(pred, target_is_real):
        """LSGAN loss (Least Squares GAN)"""
        if target_is_real:
            target = torch.ones_like(pred)
        else:
            target = torch.zeros_like(pred)
        return nn.MSELoss()(pred, target)

    @staticmethod
    def hinge_loss_discriminator(real_pred, fake_pred):
        """Hinge loss for discriminator"""
        real_loss = torch.mean(torch.relu(1.0 - real_pred))
        fake_loss = torch.mean(torch.relu(1.0 + fake_pred))
        return (real_loss + fake_loss) * 0.5

    @staticmethod
    def hinge_loss_generator(fake_pred):
        """Hinge loss for generator"""
        return -torch.mean(fake_pred)

    @staticmethod
    def vanilla_gan_loss(pred, target_is_real):
        """Standard GAN loss with BCE"""
        if target_is_real:
            target = torch.ones_like(pred)
        else:
            target = torch.zeros_like(pred)
        return nn.BCEWithLogitsLoss()(pred, target)

# %% [markdown]
# ## CycleGAN

# %% [markdown]
# ### Helpers

# %%
class lr_sched():
    def __init__(self, total_epochs=200):
        self.total_epochs = total_epochs
        self.decay_epochs = total_epochs/2

    def step(self, epoch_num):
        if epoch_num <= self.decay_epochs:
            return 1.0
        else:
            fract = (epoch_num - self.decay_epochs)  / (self.total_epochs - self.decay_epochs)
            return 1.0 - fract

# %%
def update_req_grad(models, requires_grad=True):
    for model in models:
        for param in model.parameters():
            param.requires_grad = requires_grad

# %%
class sample_fake(object):
    def __init__(self, max_imgs=50):
        self.max_imgs = max_imgs
        self.cur_img = 0
        self.imgs = list()

    def __call__(self, imgs):
        ret = list()
        for img in imgs:
            if self.cur_img < self.max_imgs:
                self.imgs.append(img)
                ret.append(img)
                self.cur_img += 1
            else:
                if np.random.ranf() > 0.5:
                    idx = np.random.randint(0, self.max_imgs)
                    ret.append(self.imgs[idx])
                    self.imgs[idx] = img
                else:
                    ret.append(img)
        return ret

# %%
def init_weights(net, init_type='normal', gain=0.02):
    def init_func(m):
        classname = m.__class__.__name__
        if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
            if init_type == 'normal':
                nn.init.normal_(m.weight.data, 0.0, gain)
            elif init_type == 'xavier':
                nn.init.xavier_normal_(m.weight.data, gain=gain)
            if hasattr(m, 'bias') and m.bias is not None:
                nn.init.constant_(m.bias.data, 0.0)
        elif classname.find('BatchNorm2d') != -1 or classname.find('InstanceNorm2d') != -1:
            if m.weight is not None:
                nn.init.normal_(m.weight.data, 1.0, gain)
            if m.bias is not None:
                nn.init.constant_(m.bias.data, 0.0)
    net.apply(init_func)

# %% [markdown]
# ### Model

# %%
class CycleGAN(nn.Module):
    def __init__(
        self,
        # generator
        in_ch=3, out_ch=3,
        epochs=20, lr=0.0002,
        cycle_weight=10.0, id_weight=5.0, adv_weight = 1.0,
        adversarial_loss_type='lsgan', # Options: 'lsgan', 'hinge', 'vanilla'
        dropout=0.5
        ):
        super().__init__()

        self.epochs = epochs
        self.lr = lr
        self.cycle_weight = cycle_weight
        self.id_weight = id_weight
        self.adv_weight = adv_weight

        self.g_ptm = UNetGenerator(in_ch, out_ch, dropout=dropout).to(device)
        self.g_mtp = UNetGenerator(out_ch, in_ch, dropout=dropout).to(device)
        self.d_m = Discriminator(in_ch).to(device)
        self.d_p = Discriminator(out_ch).to(device)

        init_weights(self.g_ptm)
        init_weights(self.g_mtp)
        init_weights(self.d_m)
        init_weights(self.d_p)

        self.l1_loss = nn.L1Loss()
        self.adversarial_loss = AdversarialLosses(adversarial_loss_type=adversarial_loss_type)

        self.adam_g = optim.Adam(
            list(self.g_ptm.parameters()) + list(self.g_mtp.parameters()),
            lr=self.lr, betas=(0.5, 0.999)
        )
        self.adam_d = optim.Adam(
            list(self.d_m.parameters()) + list(self.d_p.parameters()),
            lr=self.lr, betas=(0.5, 0.999)
        )

        self.gen_lr_scheduler = optim.lr_scheduler.LambdaLR(
            self.adam_g,
            lr_lambda=lr_sched(self.epochs).step
        )
        self.disc_lr_scheduler = optim.lr_scheduler.LambdaLR(
            self.adam_d,
            lr_lambda=lr_sched(self.epochs).step
        )

        self.sample_m = sample_fake()
        self.sample_p = sample_fake()

        self.gen_avg_losses = []
        self.disc_avg_losses = []

    def train(self, x, log_wandb=False, val_photos: list[torch.Tensor] | None = None):
        for epoch in range(self.epochs):
            start_time = time.time()

            gen_losses_identity = []
            gen_losses_cycle = []
            gen_losses_adversarial = []
            gen_losses = []

            disc_losses = []

            t = tqdm(x, leave=False, total=len(x))

            for i, (p_real, m_real) in enumerate(t):
                p_real = p_real.to(device)
                m_real = m_real.to(device)

                # Train Generator only
                update_req_grad([self.g_ptm, self.g_mtp], True)
                update_req_grad([self.d_m, self.d_p], False)
                self.adam_g.zero_grad()

                # Forward pass through generators
                m_fake = self.g_ptm(p_real)
                p_fake = self.g_mtp(m_real)

                m_cycle = self.g_ptm(p_fake)
                p_cycle = self.g_mtp(m_fake)

                m_identity = self.g_ptm(m_real)
                p_identity = self.g_mtp(p_real)

                # GenLoss = Adversarial + Cycle Consistency + Identity
                m_loss_identity = self.l1_loss(m_identity, m_real) * self.id_weight
                p_loss_identity = self.l1_loss(p_identity, p_real) * self.id_weight

                m_loss_cycle = self.l1_loss(m_cycle, m_real) * self.cycle_weight
                p_loss_cycle = self.l1_loss(p_cycle, p_real) * self.cycle_weight

                m_discriminated = self.d_m(m_fake)
                p_discriminated = self.d_p(p_fake)

                m_loss_adversarial = self.adversarial_loss.gen_adv_loss(m_discriminated) * self.adv_weight
                p_loss_adversarial = self.adversarial_loss.gen_adv_loss(p_discriminated) * self.adv_weight

                total_gen_loss = m_loss_identity + p_loss_identity + \
                                 m_loss_cycle + p_loss_cycle + \
                                 m_loss_adversarial + p_loss_adversarial

                gen_losses_identity.append(m_loss_identity.item() + p_loss_identity.item())
                gen_losses_cycle.append(m_loss_cycle.item() + p_loss_cycle.item())
                gen_losses_adversarial.append(m_loss_adversarial.item() + p_loss_adversarial.item())
                gen_losses.append(total_gen_loss.item())

                # Backward pass through generators
                total_gen_loss.backward()
                self.adam_g.step()

                # Train Discriminators only
                update_req_grad([self.g_ptm, self.g_mtp], False)
                update_req_grad([self.d_m, self.d_p], True)
                self.adam_d.zero_grad()

                # Forward pass through discriminators
                m_fake = self.sample_m([m_fake.cpu().data.numpy()])[0]
                p_fake = self.sample_p([p_fake.cpu().data.numpy()])[0]
                m_fake = torch.tensor(m_fake).to(device)
                p_fake = torch.tensor(p_fake).to(device)

                m_disc_real = self.d_m(m_real)
                m_disc_fake = self.d_m(m_fake)
                p_disc_real = self.d_p(p_real)
                p_disc_fake = self.d_p(p_fake)

                # Discriminator Loss
                m_disc_loss = self.adversarial_loss.disc_adv_loss(m_disc_real, m_disc_fake)
                p_disc_loss = self.adversarial_loss.disc_adv_loss(p_disc_real, p_disc_fake)

                total_disc_loss = m_disc_loss + p_disc_loss
                disc_losses.append(total_disc_loss.item())

                # Backward pass through discriminators
                m_disc_loss.backward()
                p_disc_loss.backward()
                self.adam_d.step()

                t.set_postfix(gen_loss=total_gen_loss.item(), disc_loss=total_disc_loss.item())

            if (epoch+1) % 5 == 0:
                save_dict = {
                    'g_ptm': self.g_ptm.state_dict(),
                    'g_mtp': self.g_mtp.state_dict(),
                    'd_m': self.d_m.state_dict(),
                    'd_p': self.d_p.state_dict(),
                    'adam_g': self.adam_g.state_dict(),
                    'adam_d': self.adam_d.state_dict(),
                    'epoch': epoch + 1
                }

                save_checkpoint(save_dict, f"checkpoint_epoch_{epoch+1}.pth")

            avg_gen_loss_identity = np.mean(gen_losses_identity)
            avg_gen_loss_cycle = np.mean(gen_losses_cycle)
            avg_gen_loss_adversarial = np.mean(gen_losses_adversarial)

            avg_gen_loss = np.mean(gen_losses)
            avg_disc_loss = np.mean(disc_losses)

            self.gen_avg_losses.append(avg_gen_loss)
            self.disc_avg_losses.append(avg_disc_loss)

            end_time = time.time()
            elapsed_time = end_time - start_time

            if log_wandb:
                metrics = {
                    "Epoch": epoch + 1,

                    "Loss/G/Total": avg_gen_loss,
                    "Loss/G/Identity": avg_gen_loss_identity,
                    "Loss/G/Cycle": avg_gen_loss_cycle,
                    "Loss/G/Adversarial": avg_gen_loss_adversarial,

                    "Loss/D/Total": avg_disc_loss,

                    "Time": elapsed_time
                }

                wandb.log(metrics)

                if val_photos is not None:
                    self.g_ptm.eval()
                    self.g_mtp.eval()
                    with torch.no_grad():
                        generated_images = []
                        for i, img in enumerate(val_photos):
                            monet_gen = self.g_ptm(img.unsqueeze(0).to(device))
                            cycle_gen = self.g_mtp(monet_gen)
                            identity_gen = self.g_mtp((img.unsqueeze(0).to(device)))

                            orig = img.cpu().numpy().transpose(1, 2, 0) * 0.5 + 0.5
                            monet = monet_gen.squeeze(0).cpu().numpy().transpose(1, 2, 0) * 0.5 + 0.5
                            cycle = cycle_gen.squeeze(0).cpu().numpy().transpose(1, 2, 0) * 0.5 + 0.5
                            identity = identity_gen.squeeze(0).cpu().numpy().transpose(1, 2, 0) * 0.5 + 0.5
                            generated_images.append([orig, monet, cycle, identity])

                        n = len(generated_images)
                        fig, axes = plt.subplots(n, 4, figsize=(16, 4 * n))
                        for i in range(n):
                            for j, (img, title) in enumerate(zip(generated_images[i], ["Photo", "Monet", "Cycle", "Identity"])):
                                ax = axes[i, j] if n > 1 else axes[j]
                                ax.imshow(np.clip(img, 0, 1))
                                ax.set_title(title)
                                ax.axis('off')
                        plt.tight_layout()
                        save_path = f"val_results_epoch_{epoch+1}.png"
                        plt.savefig(save_path)
                        plt.close(fig)

                        wandb.log({"Validation Results": wandb.Image(save_path)})
                    self.g_ptm.train()
                    self.g_mtp.train()

            print(f"Epoch {epoch+1}/{self.epochs} completed in {elapsed_time:.2f} seconds")
            print(f"Generator Loss: {avg_gen_loss:.4f}, Discriminator Loss: {avg_disc_loss:.4f}")

            self.gen_lr_scheduler.step()
            self.disc_lr_scheduler.step()

# %% [markdown]
# ### Training

# %%
cycle_weight = 7.0
adv_weight = 7.0
id_weight = 1.0
dropout = 0.5
adversarial_loss_type = 'lsgan'
cycleGAN = CycleGAN(
    epochs=EPOCHS,
    cycle_weight=cycle_weight,
    adv_weight=adv_weight,
    id_weight=id_weight,
    adversarial_loss_type=adversarial_loss_type
    )

# %%
from torchsummary import summary
summary(cycleGAN.g_mtp, (3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 258, 258]               0
#             Conv2d-2         [-1, 64, 128, 128]           3,072
#          LeakyReLU-3         [-1, 64, 128, 128]               0
#          Downblock-4         [-1, 64, 128, 128]               0
#    ReflectionPad2d-5         [-1, 64, 130, 130]               0
#             Conv2d-6          [-1, 128, 64, 64]         131,072
#     InstanceNorm2d-7          [-1, 128, 64, 64]               0
#          LeakyReLU-8          [-1, 128, 64, 64]               0
#          Downblock-9          [-1, 128, 64, 64]               0
#   ReflectionPad2d-10          [-1, 128, 66, 66]               0
#            Conv2d-11          [-1, 256, 32, 32]         524,288
#    InstanceNorm2d-12          [-1, 256, 32, 32]               0
#         LeakyReLU-13          [-1, 256, 32, 32]               0
#         Downblock-14          [-1, 256, 32, 32]               0
#   ReflectionPad2d-15          [-1, 256, 34, 34]               0
#            Conv2d-16          [-1, 512, 16, 16]       2,097,152
#    InstanceNorm2d-17          [-1, 512, 16, 16]               0
#         LeakyReLU-18          [-1, 512, 16, 16]               0
#         Downblock-19          [-1, 512, 16, 16]               0
#   ReflectionPad2d-20          [-1, 512, 18, 18]               0
#            Conv2d-21            [-1, 512, 8, 8]       4,194,304
#    InstanceNorm2d-22            [-1, 512, 8, 8]               0
#         LeakyReLU-23            [-1, 512, 8, 8]               0
#         Downblock-24            [-1, 512, 8, 8]               0
#   ReflectionPad2d-25          [-1, 512, 10, 10]               0
#            Conv2d-26            [-1, 512, 4, 4]       4,194,304
#    InstanceNorm2d-27            [-1, 512, 4, 4]               0
#         LeakyReLU-28            [-1, 512, 4, 4]               0
#         Downblock-29            [-1, 512, 4, 4]               0
#   ReflectionPad2d-30            [-1, 512, 6, 6]               0
#            Conv2d-31            [-1, 512, 2, 2]       4,194,304
#              ReLU-32            [-1, 512, 2, 2]               0
#         Downblock-33            [-1, 512, 2, 2]               0
#          Upsample-34            [-1, 512, 4, 4]               0
#              ReLU-35            [-1, 512, 4, 4]               0
#            Conv2d-36            [-1, 512, 4, 4]       2,359,296
#    InstanceNorm2d-37            [-1, 512, 4, 4]               0
#           Dropout-38            [-1, 512, 4, 4]               0
#           Upblock-39            [-1, 512, 4, 4]               0
#          Upsample-40           [-1, 1024, 8, 8]               0
#              ReLU-41           [-1, 1024, 8, 8]               0
#            Conv2d-42            [-1, 512, 8, 8]       4,718,592
#    InstanceNorm2d-43            [-1, 512, 8, 8]               0
#           Dropout-44            [-1, 512, 8, 8]               0
#           Upblock-45            [-1, 512, 8, 8]               0
#          Upsample-46         [-1, 1024, 16, 16]               0
#              ReLU-47         [-1, 1024, 16, 16]               0
#            Conv2d-48          [-1, 512, 16, 16]       4,718,592
#    InstanceNorm2d-49          [-1, 512, 16, 16]               0
#           Dropout-50          [-1, 512, 16, 16]               0
#           Upblock-51          [-1, 512, 16, 16]               0
#          Upsample-52         [-1, 1024, 32, 32]               0
#              ReLU-53         [-1, 1024, 32, 32]               0
#            Conv2d-54          [-1, 256, 32, 32]       2,359,296
#    InstanceNorm2d-55          [-1, 256, 32, 32]               0
#           Upblock-56          [-1, 256, 32, 32]               0
#          Upsample-57          [-1, 512, 64, 64]               0
#              ReLU-58          [-1, 512, 64, 64]               0
#            Conv2d-59          [-1, 128, 64, 64]         589,824
#    InstanceNorm2d-60          [-1, 128, 64, 64]               0
#           Upblock-61          [-1, 128, 64, 64]               0
#          Upsample-62        [-1, 256, 128, 128]               0
#              ReLU-63        [-1, 256, 128, 128]               0
#            Conv2d-64         [-1, 64, 128, 128]         147,456
#    InstanceNorm2d-65         [-1, 64, 128, 128]               0
#           Upblock-66         [-1, 64, 128, 128]               0
#          Upsample-67        [-1, 128, 256, 256]               0
#            Conv2d-68          [-1, 3, 256, 256]           3,456
#           Upblock-69          [-1, 3, 256, 256]               0
#              Tanh-70          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 30,235,008
# Trainable params: 30,235,008
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 304.26
# Params size (MB): 115.34
# Estimated Total Size (MB): 420.34
# ----------------------------------------------------------------

# %%
save_dict = {
    'g_ptm': cycleGAN.g_ptm.state_dict(),
}

save_checkpoint(save_dict, "cyclegan_initial.pth")

# %%
config = {
    'epochs': EPOCHS,
    'batch_size': BATCH_SIZE,
    'architecture': 'CycleGAN',
    'generator': 'UNet-Based-Generator',
    'discriminator': 'PatchGAN-Discriminator',
    'adversarial_loss': 'LSGAN',
    'description': 'LSGAN full training',
    'cycle_weight': cycle_weight,
    'adv_weight': adv_weight,
    'id_weight': id_weight,
    'dropout': dropout,
}

# %%
config
# Out:
# {'epochs': 30,
#  'batch_size': 1,
#  'architecture': 'CycleGAN',
#  'generator': 'UNet-Based-Generator',
#  'discriminator': 'PatchGAN-Discriminator',
#  'adversarial_loss': 'LSGAN',
#  'description': 'LSGAN full training',
#  'cycle_weight': 7.0,
#  'adv_weight': 7.0,
#  'id_weight': 1.0,
#  'dropout': 0.5}

# %%
def get_model_summary(model, input_size, device):
    f = io.StringIO()
    with redirect_stdout(f):
        summary(model, input_size=input_size, device=str(device))
    return f.getvalue()

# %%
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: dachis (dachis-none) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
with wandb.init(
    project='monet',
    config=config,
    name='CycleGAN_UNet_lsgan_30'):

    print('\nmodel summary\n')
    print('Generator Photo to Monet:\n')
    summary(cycleGAN.g_ptm, input_size=(3, 256, 256), device=str(device))
    print('\nGenerator Monet to Photo:\n')
    summary(cycleGAN.g_mtp, input_size=(3, 256, 256), device=str(device))
    print('\nDiscriminator Monet:\n')
    summary(cycleGAN.d_m, input_size=(3, 256, 256), device=str(device))
    print('\nDiscriminator Photo:\n')
    summary(cycleGAN.d_p, input_size=(3, 256, 256), device=str(device))

    gen_ptm_summary = get_model_summary(cycleGAN.g_ptm, (3, 256, 256), device)
    gen_mtp_summary = get_model_summary(cycleGAN.g_mtp, (3, 256, 256), device)
    disc_m_summary = get_model_summary(cycleGAN.d_m, (3, 256, 256), device)
    disc_p_summary = get_model_summary(cycleGAN.d_p, (3, 256, 256), device)

    wandb.log({
        'Model Summary': wandb.Table(data=[
            ['Generator Photo to Monet', gen_ptm_summary],
            ['Generator Monet to Photo', gen_mtp_summary],
            ['Discriminator Monet', disc_m_summary],
            ['Discriminator Photo', disc_p_summary],
        ],
        columns=['Model', 'Summary'])})

    print('\ntraining\n')

    wandb.watch(cycleGAN.g_ptm, log='gradients', log_freq=5000, log_graph=False)

    cycleGAN.train(img_dl, log_wandb=True, val_photos=val_photos)

    # save_dict = {
    #     'g_ptm': cycleGAN.g_ptm.state_dict(),
    # }

    # checkpoint_path = "cyclegan_final.pth"
    # save_checkpoint(save_dict, checkpoint_path)

    # wandb.save(checkpoint_path)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251227_113915-1jxg9cyx</code>
# Syncing run <strong><a href='https://wandb.ai/dachis-none/monet/runs/1jxg9cyx' target="_blank">CycleGAN_UNet_lsgan_30</a></strong> to <a href='https://wandb.ai/dachis-none/monet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dachis-none/monet' target="_blank">https://wandb.ai/dachis-none/monet</a>
#  View run at <a href='https://wandb.ai/dachis-none/monet/runs/1jxg9cyx' target="_blank">https://wandb.ai/dachis-none/monet/runs/1jxg9cyx</a>
# model summary
#
# Generator Photo to Monet:
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 258, 258]               0
#             Conv2d-2         [-1, 64, 128, 128]           3,072
#          LeakyReLU-3         [-1, 64, 128, 128]               0
#          Downblock-4         [-1, 64, 128, 128]               0
#    ReflectionPad2d-5         [-1, 64, 130, 130]               0
#             Conv2d-6          [-1, 128, 64, 64]         131,072
#     InstanceNorm2d-7          [-1, 128, 64, 64]               0
#          LeakyReLU-8          [-1, 128, 64, 64]               0
#          Downblock-9          [-1, 128, 64, 64]               0
#   ReflectionPad2d-10          [-1, 128, 66, 66]               0
#            Conv2d-11          [-1, 256, 32, 32]         524,288
#    InstanceNorm2d-12          [-1, 256, 32, 32]               0
#         LeakyReLU-13          [-1, 256, 32, 32]               0
#         Downblock-14          [-1, 256, 32, 32]               0
#   ReflectionPad2d-15          [-1, 256, 34, 34]               0
#            Conv2d-16          [-1, 512, 16, 16]       2,097,152
#    InstanceNorm2d-17          [-1, 512, 16, 16]               0
#         LeakyReLU-18          [-1, 512, 16, 16]               0
#         Downblock-19          [-1, 512, 16, 16]               0
#   ReflectionPad2d-20          [-1, 512, 18, 18]               0
#            Conv2d-21            [-1, 512, 8, 8]       4,194,304
#    InstanceNorm2d-22            [-1, 512, 8, 8]               0
#         LeakyReLU-23            [-1, 512, 8, 8]               0
#         Downblock-24            [-1, 512, 8, 8]               0
#   ReflectionPad2d-25          [-1, 512, 10, 10]               0
#            Conv2d-26            [-1, 512, 4, 4]       4,194,304
#    InstanceNorm2d-27            [-1, 512, 4, 4]               0
#         LeakyReLU-28            [-1, 512, 4, 4]               0
#         Downblock-29            [-1, 512, 4, 4]               0
#   ReflectionPad2d-30            [-1, 512, 6, 6]               0
#            Conv2d-31            [-1, 512, 2, 2]       4,194,304
#              ReLU-32            [-1, 512, 2, 2]               0
#         Downblock-33            [-1, 512, 2, 2]               0
#          Upsample-34            [-1, 512, 4, 4]               0
#              ReLU-35            [-1, 512, 4, 4]               0
#            Conv2d-36            [-1, 512, 4, 4]       2,359,296
#    InstanceNorm2d-37            [-1, 512, 4, 4]               0
#           Dropout-38            [-1, 512, 4, 4]               0
#           Upblock-39            [-1, 512, 4, 4]               0
#          Upsample-40           [-1, 1024, 8, 8]               0
#              ReLU-41           [-1, 1024, 8, 8]               0
#            Conv2d-42            [-1, 512, 8, 8]       4,718,592
#    InstanceNorm2d-43            [-1, 512, 8, 8]               0
#           Dropout-44            [-1, 512, 8, 8]               0
#           Upblock-45            [-1, 512, 8, 8]               0
#          Upsample-46         [-1, 1024, 16, 16]               0
#              ReLU-47         [-1, 1024, 16, 16]               0
#            Conv2d-48          [-1, 512, 16, 16]       4,718,592
#    InstanceNorm2d-49          [-1, 512, 16, 16]               0
#           Dropout-50          [-1, 512, 16, 16]               0
#           Upblock-51          [-1, 512, 16, 16]               0
#          Upsample-52         [-1, 1024, 32, 32]               0
#              ReLU-53         [-1, 1024, 32, 32]               0
#            Conv2d-54          [-1, 256, 32, 32]       2,359,296
#    InstanceNorm2d-55          [-1, 256, 32, 32]               0
#           Upblock-56          [-1, 256, 32, 32]               0
#          Upsample-57          [-1, 512, 64, 64]               0
#              ReLU-58          [-1, 512, 64, 64]               0
#            Conv2d-59          [-1, 128, 64, 64]         589,824
#    InstanceNorm2d-60          [-1, 128, 64, 64]               0
#           Upblock-61          [-1, 128, 64, 64]               0
#          Upsample-62        [-1, 256, 128, 128]               0
#              ReLU-63        [-1, 256, 128, 128]               0
#            Conv2d-64         [-1, 64, 128, 128]         147,456
#    InstanceNorm2d-65         [-1, 64, 128, 128]               0
#           Upblock-66         [-1, 64, 128, 128]               0
#          Upsample-67        [-1, 128, 256, 256]               0
#            Conv2d-68          [-1, 3, 256, 256]           3,456
#           Upblock-69          [-1, 3, 256, 256]               0
#              Tanh-70          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 30,235,008
# Trainable params: 30,235,008
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 304.26
# Params size (MB): 115.34
# Estimated Total Size (MB): 420.34
# ----------------------------------------------------------------
#
# Generator Monet to Photo:
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 258, 258]               0
#             Conv2d-2         [-1, 64, 128, 128]           3,072
#          LeakyReLU-3         [-1, 64, 128, 128]               0
#          Downblock-4         [-1, 64, 128, 128]               0
#    ReflectionPad2d-5         [-1, 64, 130, 130]               0
#             Conv2d-6          [-1, 128, 64, 64]         131,072
#     InstanceNorm2d-7          [-1, 128, 64, 64]               0
#          LeakyReLU-8          [-1, 128, 64, 64]               0
#          Downblock-9          [-1, 128, 64, 64]               0
#   ReflectionPad2d-10          [-1, 128, 66, 66]               0
#            Conv2d-11          [-1, 256, 32, 32]         524,288
#    InstanceNorm2d-12          [-1, 256, 32, 32]               0
#         LeakyReLU-13          [-1, 256, 32, 32]               0
#         Downblock-14          [-1, 256, 32, 32]               0
#   ReflectionPad2d-15          [-1, 256, 34, 34]               0
#            Conv2d-16          [-1, 512, 16, 16]       2,097,152
#    InstanceNorm2d-17          [-1, 512, 16, 16]               0
#         LeakyReLU-18          [-1, 512, 16, 16]               0
#         Downblock-19          [-1, 512, 16, 16]               0
#   ReflectionPad2d-20          [-1, 512, 18, 18]               0
#            Conv2d-21            [-1, 512, 8, 8]       4,194,304
#    InstanceNorm2d-22            [-1, 512, 8, 8]               0
#         LeakyReLU-23            [-1, 512, 8, 8]               0
#         Downblock-24            [-1, 512, 8, 8]               0
#   ReflectionPad2d-25          [-1, 512, 10, 10]               0
#            Conv2d-26            [-1, 512, 4, 4]       4,194,304
#    InstanceNorm2d-27            [-1, 512, 4, 4]               0
#         LeakyReLU-28            [-1, 512, 4, 4]               0
#         Downblock-29            [-1, 512, 4, 4]               0
#   ReflectionPad2d-30            [-1, 512, 6, 6]               0
#            Conv2d-31            [-1, 512, 2, 2]       4,194,304
#              ReLU-32            [-1, 512, 2, 2]               0
#         Downblock-33            [-1, 512, 2, 2]               0
#          Upsample-34            [-1, 512, 4, 4]               0
#              ReLU-35            [-1, 512, 4, 4]               0
#            Conv2d-36            [-1, 512, 4, 4]       2,359,296
#    InstanceNorm2d-37            [-1, 512, 4, 4]               0
#           Dropout-38            [-1, 512, 4, 4]               0
#           Upblock-39            [-1, 512, 4, 4]               0
#          Upsample-40           [-1, 1024, 8, 8]               0
#              ReLU-41           [-1, 1024, 8, 8]               0
#            Conv2d-42            [-1, 512, 8, 8]       4,718,592
#    InstanceNorm2d-43            [-1, 512, 8, 8]               0
#           Dropout-44            [-1, 512, 8, 8]               0
#           Upblock-45            [-1, 512, 8, 8]               0
#          Upsample-46         [-1, 1024, 16, 16]               0
#              ReLU-47         [-1, 1024, 16, 16]               0
#            Conv2d-48          [-1, 512, 16, 16]       4,718,592
#    InstanceNorm2d-49          [-1, 512, 16, 16]               0
#           Dropout-50          [-1, 512, 16, 16]               0
#           Upblock-51          [-1, 512, 16, 16]               0
#          Upsample-52         [-1, 1024, 32, 32]               0
#              ReLU-53         [-1, 1024, 32, 32]               0
#            Conv2d-54          [-1, 256, 32, 32]       2,359,296
#    InstanceNorm2d-55          [-1, 256, 32, 32]               0
#           Upblock-56          [-1, 256, 32, 32]               0
#          Upsample-57          [-1, 512, 64, 64]               0
#              ReLU-58          [-1, 512, 64, 64]               0
#            Conv2d-59          [-1, 128, 64, 64]         589,824
#    InstanceNorm2d-60          [-1, 128, 64, 64]               0
#           Upblock-61          [-1, 128, 64, 64]               0
#          Upsample-62        [-1, 256, 128, 128]               0
#              ReLU-63        [-1, 256, 128, 128]               0
#            Conv2d-64         [-1, 64, 128, 128]         147,456
#    InstanceNorm2d-65         [-1, 64, 128, 128]               0
#           Upblock-66         [-1, 64, 128, 128]               0
#          Upsample-67        [-1, 128, 256, 256]               0
#            Conv2d-68          [-1, 3, 256, 256]           3,456
#           Upblock-69          [-1, 3, 256, 256]               0
#              Tanh-70          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 30,235,008
# Trainable params: 30,235,008
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 304.26
# Params size (MB): 115.34
# Estimated Total Size (MB): 420.34
# ----------------------------------------------------------------
#
# Discriminator Monet:
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 258, 258]               0
#             Conv2d-2         [-1, 64, 128, 128]           3,136
#          LeakyReLU-3         [-1, 64, 128, 128]               0
#          Downblock-4         [-1, 64, 128, 128]               0
#    ReflectionPad2d-5         [-1, 64, 130, 130]               0
#             Conv2d-6          [-1, 128, 64, 64]         131,200
#     InstanceNorm2d-7          [-1, 128, 64, 64]               0
#          LeakyReLU-8          [-1, 128, 64, 64]               0
#          Downblock-9          [-1, 128, 64, 64]               0
#   ReflectionPad2d-10          [-1, 128, 66, 66]               0
#            Conv2d-11          [-1, 256, 32, 32]         524,544
#    InstanceNorm2d-12          [-1, 256, 32, 32]               0
#         LeakyReLU-13          [-1, 256, 32, 32]               0
#         Downblock-14          [-1, 256, 32, 32]               0
#   ReflectionPad2d-15          [-1, 256, 34, 34]               0
#            Conv2d-16          [-1, 512, 31, 31]       2,097,664
#    InstanceNorm2d-17          [-1, 512, 31, 31]               0
#         LeakyReLU-18          [-1, 512, 31, 31]               0
#         Downblock-19          [-1, 512, 31, 31]               0
#            Conv2d-20            [-1, 1, 30, 30]           8,193
# ================================================================
# Total params: 2,764,737
# Trainable params: 2,764,737
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 79.31
# Params size (MB): 10.55
# Estimated Total Size (MB): 90.61
# ----------------------------------------------------------------
#
# Discriminator Photo:
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ReflectionPad2d-1          [-1, 3, 258, 258]               0
#             Conv2d-2         [-1, 64, 128, 128]           3,136
#          LeakyReLU-3         [-1, 64, 128, 128]               0
#          Downblock-4         [-1, 64, 128, 128]               0
#    ReflectionPad2d-5         [-1, 64, 130, 130]               0
#             Conv2d-6          [-1, 128, 64, 64]         131,200
#     InstanceNorm2d-7          [-1, 128, 64, 64]               0
#          LeakyReLU-8          [-1, 128, 64, 64]               0
#          Downblock-9          [-1, 128, 64, 64]               0
#   ReflectionPad2d-10          [-1, 128, 66, 66]               0
#            Conv2d-11          [-1, 256, 32, 32]         524,544
#    InstanceNorm2d-12          [-1, 256, 32, 32]               0
#         LeakyReLU-13          [-1, 256, 32, 32]               0
#         Downblock-14          [-1, 256, 32, 32]               0
#   ReflectionPad2d-15          [-1, 256, 34, 34]               0
#            Conv2d-16          [-1, 512, 31, 31]       2,097,664
#    InstanceNorm2d-17          [-1, 512, 31, 31]               0
#         LeakyReLU-18          [-1, 512, 31, 31]               0
#         Downblock-19          [-1, 512, 31, 31]               0
#            Conv2d-20            [-1, 1, 30, 30]           8,193
# ================================================================
# Total params: 2,764,737
# Trainable params: 2,764,737
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 79.31
# Params size (MB): 10.55
# Estimated Total Size (MB): 90.61
# ----------------------------------------------------------------
#
# training
#   7%|▋         | 21/300 [00:06<01:13,  3.80it/s, disc_loss=1.44, gen_loss=19.7]

# %%
cycleGAN.train(img_dl, log_wandb=False, val_photos=val_photos)
# Out:
# Epoch 1/30 completed in 81.13 seconds
# Generator Loss: 12.0886, Discriminator Loss: 0.9414
# Epoch 2/30 completed in 81.29 seconds
# Generator Loss: 7.3310, Discriminator Loss: 0.5790
# Epoch 3/30 completed in 81.15 seconds
# Generator Loss: 6.9905, Discriminator Loss: 0.5716
# Epoch 4/30 completed in 81.22 seconds
# Generator Loss: 6.7522, Discriminator Loss: 0.5597
# Epoch 5/30 completed in 85.15 seconds
# Generator Loss: 6.4494, Discriminator Loss: 0.5583
# Epoch 6/30 completed in 81.35 seconds
# Generator Loss: 6.4350, Discriminator Loss: 0.5661
# Epoch 7/30 completed in 81.19 seconds
# Generator Loss: 6.2743, Discriminator Loss: 0.5415
# Epoch 8/30 completed in 81.20 seconds
# Generator Loss: 6.2955, Discriminator Loss: 0.5538
# Epoch 9/30 completed in 81.21 seconds
# Generator Loss: 6.1914, Discriminator Loss: 0.5421
# Epoch 10/30 completed in 88.50 seconds
# Generator Loss: 6.2240, Discriminator Loss: 0.5408
# Epoch 11/30 completed in 81.50 seconds
# Generator Loss: 6.2998, Discriminator Loss: 0.5466
# Epoch 12/30 completed in 81.36 seconds
# Generator Loss: 6.1540, Discriminator Loss: 0.5399
# Epoch 13/30 completed in 81.29 seconds
# Generator Loss: 6.1080, Discriminator Loss: 0.5366
# Epoch 14/30 completed in 81.36 seconds
# Generator Loss: 6.1589, Discriminator Loss: 0.5379
# Epoch 15/30 completed in 83.87 seconds
# Generator Loss: 6.0799, Discriminator Loss: 0.5364
# Epoch 16/30 completed in 81.44 seconds
# Generator Loss: 6.0893, Discriminator Loss: 0.5385
# Epoch 17/30 completed in 81.39 seconds
# Generator Loss: 5.9662, Discriminator Loss: 0.5174
# Epoch 18/30 completed in 81.53 seconds
# Generator Loss: 6.0090, Discriminator Loss: 0.5163
# Epoch 19/30 completed in 81.34 seconds
# Generator Loss: 5.9556, Discriminator Loss: 0.5151
# Epoch 20/30 completed in 85.80 seconds
# Generator Loss: 5.8839, Discriminator Loss: 0.5069
# Epoch 21/30 completed in 81.56 seconds
# Generator Loss: 5.8640, Discriminator Loss: 0.5047
# Epoch 22/30 completed in 81.58 seconds
# Generator Loss: 5.9966, Discriminator Loss: 0.4957
# Epoch 23/30 completed in 81.39 seconds
# Generator Loss: 5.8293, Discriminator Loss: 0.4957
# Epoch 24/30 completed in 81.50 seconds
# Generator Loss: 5.9034, Discriminator Loss: 0.4904
# Epoch 25/30 completed in 84.36 seconds
# Generator Loss: 5.8435, Discriminator Loss: 0.4894
# Epoch 26/30 completed in 81.54 seconds
# Generator Loss: 5.8798, Discriminator Loss: 0.4821
# Epoch 27/30 completed in 81.49 seconds
# Generator Loss: 5.9214, Discriminator Loss: 0.4790
# Epoch 28/30 completed in 81.37 seconds
# Generator Loss: 5.9302, Discriminator Loss: 0.4749
# Epoch 29/30 completed in 81.31 seconds
# Generator Loss: 5.9566, Discriminator Loss: 0.4664
# Epoch 30/30 completed in 89.10 seconds
# Generator Loss: 5.9782, Discriminator Loss: 0.4645

# %% [markdown]
# # FiD

# %%
def save_real_and_generated(netG, dataloader, real_dir, fake_dir, n_images=300, device=device):
    os.makedirs(real_dir, exist_ok=True)
    os.makedirs(fake_dir, exist_ok=True)
    to_pil = transforms.ToPILImage()
    saved = 0

    netG.eval()
    with torch.no_grad():
        for photos, monets in dataloader:
            for i in range(photos.size(0)):
                if saved >= n_images:
                    return
                # real target (monet) -> unnormalize from [-1,1] to [0,1]
                real = monets[i].cpu() * 0.5 + 0.5
                real_pil = to_pil(torch.clamp(real, 0.0, 1.0))
                real_pil.save(os.path.join(real_dir, f"real_{saved:05d}.png"))

                # generate and save fake -> unnormalize
                photo = photos[i].unsqueeze(0).to(device)
                fake = netG(photo).squeeze(0).cpu() * 0.5 + 0.5
                fake_pil = to_pil(torch.clamp(fake, 0.0, 1.0))
                fake_pil.save(os.path.join(fake_dir, f"fake_{saved:05d}.png"))

                saved += 1

# %%
real_dir = './real'
fake_dir = './fake'

save_real_and_generated(cycleGAN.g_ptm, img_dl, real_dir, fake_dir)

# %%
# !pip install pytorch-fid -q
# !python -m pytorch_fid ./real ./fake
# Out:
# 100% 6/6 [00:02<00:00,  2.73it/s]
# 100% 6/6 [00:01<00:00,  3.53it/s]
# FID:  136.8599200317104
